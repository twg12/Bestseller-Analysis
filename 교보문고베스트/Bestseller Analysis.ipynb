# %%
# Bestseller Analysis
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
for font in fm.fontManager.ttflist:
    if font.name in ['AppleGothic', 'Malgun Gothic']:
        plt.rcParams['font.family'] = font.name
        break
plt.rcParams['font.family']

# %matplotlib inline
mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams["axes.grid"] = True
plt.rcParams["figure.figsize"] = (14,4)

# %%
print ('버전: ', mpl.__version__)
print ('설치 위치: ', mpl.__file__)
print ('설정 위치: ', mpl.get_configdir())
print ('캐시 위치: ', mpl.get_cachedir())
# Out:
# 버전:  3.1.0
# 설치 위치:  C:\Users\user\Anaconda3\lib\site-packages\matplotlib\__init__.py
# 설정 위치:  C:\Users\user\.matplotlib
# 캐시 위치:  C:\Users\user\.matplotlib

# %%
B2000 = pd.read_csv('베스트_2000.csv', encoding = 'cp949', sep = ';')
B2001 = pd.read_csv('베스트_2001.csv', encoding = 'cp949', sep = ';')
B2002 = pd.read_csv('베스트_2002.csv', encoding = 'cp949', sep = ';')
B2003 = pd.read_csv('베스트_2003.csv', encoding = 'cp949', sep = ';')
B2004 = pd.read_csv('베스트_2004.csv', encoding = 'cp949', sep = ';')
B2005 = pd.read_csv('베스트_2005.csv', encoding = 'cp949', sep = ';')
B2006 = pd.read_csv('베스트_2006.csv', encoding = 'cp949', sep = ';')
B2007 = pd.read_csv('베스트_2007.csv', encoding = 'cp949', sep = ';')
B2008 = pd.read_csv('베스트_2008.csv', encoding = 'cp949', sep = ';')
B2009 = pd.read_csv('베스트_2009.csv', encoding = 'cp949', sep = ';')
B2010 = pd.read_csv('베스트_2010.csv', encoding = 'cp949', sep = ';')
B2011 = pd.read_csv('베스트_2011.csv', encoding = 'cp949', sep = ';')
B2012 = pd.read_csv('베스트_2012.csv', encoding = 'cp949', sep = ';')
B2013 = pd.read_csv('베스트_2013.csv', encoding = 'cp949', sep = ';')
B2014 = pd.read_csv('베스트_2014.csv', encoding = 'cp949', sep = ';')
B2015 = pd.read_csv('베스트_2015.csv', encoding = 'cp949', sep = ';')
B2016 = pd.read_csv('베스트_2016.csv', encoding = 'cp949', sep = ';')
B2017 = pd.read_csv('베스트_2017.csv', encoding = 'cp949', sep = ';')
B2018 = pd.read_csv('베스트_2018.csv', encoding = 'cp949', sep = ';')

years = [B2000, B2001, B2002, B2003, B2004, B2005, B2006, B2007, B2008, B2009, B2010, B2011, B2012, B2013, B2014, B2015, B2016, B2017, B2018]

# %%
years
# Out:
# [    순위           ISBN                                도서명        저자명  \
#  0    1  9788984370067                               가시고기        조창인
#  1    2  9788983920683                 해리포터와 마법사의 돌 제1권 1   조앤 K. 롤링
#  2    3  9788982732362                    부자 아빠 가난한 아빠. 1   로버트 기요사키
#  3    4  9788988045930                          국화꽃 향기. 1        김하인
#  4    5  9788986167511                      영어공부 절대로 하지마라        정찬용
#  5    6  9788983920706                  해리포터와 비밀의 방 제2권 1   조앤 K. 롤링
#  6    7  9788980103034                      누가 내 치즈를 옮겼을까     스펜서 존슨
#  7    8  9788980381319                      느리게 산다는 것의 의미     피에르 쌍소
#  8    9  9788982640919                         노자와 21세기 1        김용옥
#  9   10  9788970632070                   만행 하버드에서 화계사까지 1         현각
#  10  11  9788970631578         지금 알고 있는 걸 그때도 알았더라면(잠언시집)        류시화
#  11  12  9788970120157                  상실의 시대:원제 노르웨이의 숲   무라카미 하루키
#  12  13  9788934904700         새 먼나라 이웃나라 7:일본 1(일본.일본인편)        이원복
#  13  14  9788985599214                             오두막 편지         법정
#  14  15  9788987724898                         한 사람을 사랑했네        이정하
#  15  16  9788931413298  플래시 4 애니메이션 홈페이지 만들기(할수있다)(S/W포함)        장일호
#  16  17  9788972881216                   인간경영(도쿠가와 이에야스의)     도몬 후유지
#  17  18  9788908041318             무소유(2판)(양장본 HardCover)         법정
#  18  19  9788939203822                체 게바라 평전(역사인물찾기 10)     장 코르미에
#  19  20  9788970571485                            명탐정 뚱딴지        김우영
#  20  21  9788974561383                           아라리 난장 1        김주영
#  21  22  9788978910972               시도하지 않으면 아무것도 할 수 없다     지그 지글러
#  22  23  9788979440997      당신이 그리운 건 내게서 조금 떨어져 있기 때문입니다      이정하 외
#  23  24  9788901029351                  이윤기의 그리스 로마 신화. 1        이윤기
#  24  25  9788986167658                       아직도 영어공부 하니?        정찬용
#  25  26  9788985599221                                 풍경         원성
#  26  27  9788936806156               나는 초단타매매로 매일 40만원 번다        최원철
#  27  28  9788932011523                                딸기밭        신경숙
#  28  29  9788931413144                       인터넷 비즈니스.COM        김진우
#  29  30  9788975600456                인터넷 무작정 따라하기(S/W포함)        유해룡
#  30  31  9788970123455     시인의 별(제24회 이상문학상 수상작품집 2000년도)        이인화
#  31  32  9788995015902                             창가의 토토  구로야나기 테츠코
#  32  33  9788973373338                 남자처럼 일하고 여자처럼 승리하라     게일 에반스
#  33  34  9788988246207        나도 모르게 당신께 익숙해 진것을 알게 되었습니다         예반
#  34  35  9788987871431                        그러니까 당신도 살아    오히라 미쓰요
#  35  36  9788970632056                                항아리        정호승
#  36  37  9788931001068                     어린왕자(에버그린북스 2)      생떽쥐뻬리
#  37  38  9788987268545                화성에서 온 남자 금성에서 온 여자      존 그레이
#  38  39  9788973220465                             우동 한그릇     구리 료헤이
#  39  40  9788973373284                           코리아 닷컴 1        김진명
#  40  41  9788982812323                                철도원     아사다 지로
#  41  42  9788936433369                          오래된 정원(상)        황석영
#  42  43  9788935203673                      빌게이츠 @ 생각의 속도      빌 게이츠
#  43  44  9788988878019              영어명문 BEST 20(꼭 외워야 할)        김영숙
#  44  45  9788988964040                 백지연의 선택 나는 나를 경영한다        백지연
#  45  46  9788975272011                               올인 1        노승일
#  46  47  9788971842614                       간절히 @ 두려움 없이        전여옥
#  47  48  9788988798218               최고경영자 예수 (JESUS CEO)   로리 베스 존스
#  48  49  9788982640964                             도올논어 1        김용옥
#  49  50  9788901028514                 나쁜 어린이 표(웅진 푸른 교실)        황선미
#
#           출판사명       출간일       분야       정가
#  0        밝은세상  20000110       소설   \7,500
#  1        문학수첩  20091005       소설   \8,000
#  2        황금가지  20090302    경제/경영  \12,000
#  3       생각의나무  20090420       소설   \8,800
#  4        사회평론  19990719      외국어   \6,500
#  5        문학수첩  20091005       소설   \8,000
#  6       진명출판사  20000315     자기계발   \7,000
#  7         동문선  20000620    시/에세이   \7,000
#  8         통나무  19991111       인문   \6,500
#  9         열림원  19991105    시/에세이   \7,000
#  10        열림원  19980410    시/에세이   \7,500
#  11      문학사상사  19890601       소설   \6,200
#  12        김영사  20000112  어린이(초등)   \7,900
#  13         이레  19991215    시/에세이   \7,000
#  14      자음과모음  20000108    시/에세이   \5,500
#  15       영진닷컴  20000103   컴퓨터/IT  \23,000
#  16       작가정신  20000315    경제/경영  \12,000
#  17        범우사  19990805    시/에세이   \8,000
#  18      실천문학사  20000305    정치/사회  \12,000
#  19     파랑새어린이  19991215  어린이(초등)   \7,500
#  20        문이당  20000620       소설   \8,500
#  21        큰나무  20000620     자기계발   \7,000
#  22      책만드는집  19990703    시/에세이   \5,000
#  23       웅진닷컴  20000626    역사/문화  \12,000
#  24       사회평론  20000613      외국어   \6,500
#  25         이레  19990830    시/에세이   \8,000
#  26      청아출판사  20000407    경제/경영   \9,000
#  27     문학과지성사  20000228       소설  \11,000
#  28       영진닷컴  19991110    경제/경영  \19,500
#  29         길벗  19991104   컴퓨터/IT  \16,500
#  30      문학사상사  20000125       소설  \12,000
#  31  프로메테우스출판사  20000601       소설   \7,500
#  32      해냄출판사  20000730     자기계발   \8,500
#  33       징검다리  19990616    시/에세이   \5,800
#  34       북하우스  20000710    시/에세이  \10,000
#  35        열림원  19991020       소설   \7,000
#  36      문예출판사  19991215       소설   \6,000
#  37         친구  19931201     자기계발   \9,000
#  38        청조사  19890701       소설   \7,500
#  39      해냄출판사  20000620       소설   \7,500
#  40       문학동네  20120521       소설  \12,000
#  41     창작과비평사  20000502       소설  \14,000
#  42       청림출판  20060705    경제/경영  \13,000
#  43      미국영어사  19991220      외국어   \8,800
#  44         다우  20000420    시/에세이   \8,000
#  45         들녘  20000623       소설   \8,000
#  46        푸른숲  19991222    시/에세이   \8,700
#  47         한언  20011215     자기계발   \9,800
#  48        통나무  20001010       인문   \8,500
#  49       웅진닷컴  19991220  어린이(초등)   \7,000  ,
#      순위         ISBN                                 도서명            저자명  \
#  0    1  9,78898E+12                       누가 내 치즈를 옮겼을까         스펜서 존슨
#  1    2  9,78899E+12                                상도 1            최인호
#  2    3  9,78899E+12                           국화꽃 향기. 1            김하인
#  3    4  9,78898E+12                     부자 아빠 가난한 아빠. 1       로버트 기요사키
#  4    5  9,78899E+12   블루데이북(The Blue Day Book Series 1)   브래들리 트레버 그리브
#  5    6  9,78898E+12                                가시고기            조창인
#  6    7   9,7889E+12                   이윤기의 그리스 로마 신화. 1            이윤기
#  7    8  9,78898E+12                       느리게 산다는 것의 의미         피에르 쌍소
#  8    9  9,78898E+12                  해리포터와 마법사의 돌 제1권 1       조앤 K. 롤링
#  9   10  9,78899E+12                            힐링 소사이어티            이승헌
#  10  11  9,78899E+12                          펄떡이는 물고기처럼      스티븐 C. 런딘
#  11  12  9,78898E+12       ENGLISH EXPRESSION DICTIONARY            신재용
#  12  13  9,78898E+12                          WORD SMART       애덤 로빈슨 외
#  13  14  9,78897E+12             상실의 시대(원제: 노르웨이의 숲)(3판)       무라카미 하루키
#  14  15  9,78899E+12        영어공부 절대로 하지마라(일반용)(TAPE2개포함)            정찬용
#  15  16    9,789E+12                              창가의 토토      구로야나기 테츠코
#  16  17  9,78899E+12                                  거울             원성
#  17  18  9,78894E+12                           아주 오래된 농담            박완서
#  18  19  9,78893E+12                 호밀밭의 파수꾼(문예세계문학선 3)      J. D. 샐린저
#  19  20  9,78895E+12                                  겅호         켄 블랜차드
#  20  21  9,78899E+12               아들아 머뭇거리기에는 인생이 너무 짧다            강헌구
#  21  22  9,78899E+12                              협상의 법칙          허브 코헨
#  22  23  9,78893E+12  TOEIC 답이 보인다 21세기형(T:3포함)(개정판)(2판)            김대균
#  23  24  9,78894E+12               그리스 로마 신화 1(올림포스의 신들)        토머스 볼핀치
#  24  25  9,78898E+12                   일 잘하는 사람 일 못하는 사람        호리바 마사오
#  25  26  9,78897E+12          지금 알고 있는 걸 그때도 알았더라면(잠언시집)            류시화
#  26  27  9,78897E+12          부석사(제25회이상문학상수상작품집 2001년도)            신경숙
#  27  28  9,78899E+12                 화성에서 온 남자 금성에서 온 여자          존 그레이
#  28  29  9,78897E+12                           너 그거 아니 ?     디비딕 닷컴 네티즌
#  29  30  9,78897E+12                          한비야의 중국견문록            한비야
#  30  31  9,78899E+12                              사슴벌레여자            윤대녕
#  31  32  9,78894E+12                              마이너 리그            은희경
#  32  33  9,78895E+12                         디지몬 캐릭터 대도감      대원씨아이 편집부
#  33  34  9,78894E+12                           프로페셔널의 조건         피터 드러커
#  34  35  9,78898E+12                                바이올렛            신경숙
#  35  36    9,789E+12             미국 영어발음 무작정 따라하기(T:2포함)           릭킴 외
#  36  37  9,78898E+12                      사람은 무엇으로 사는가 1           톨스토이
#  37  38  9,78895E+12                     디지몬 어드벤처를 찾아라 1      학산문화사 편집부
#  38  39  9,78893E+12                   향수(양장본 HardCover)      파트리크 쥐스킨트
#  39  40  9,78899E+12                       꿈을 도둑맞은 사람들에게          잭 캔필드
#  40  41  9,78894E+12                             야베스의 기도        브루스 윌킨슨
#  41  42  9,78893E+12                           원칙중심의 리더십         스티븐 코비
#  42  43  9,78898E+12                                등대지기            조창인
#  43  44  9,78895E+12                경제기사는 돈이다(2001)(개정판)            송양민
#  44  45  9,78891E+12              무소유(2판)(양장본 HardCover)             법정
#  45  46  9,78894E+12                                  손님            황석영
#  46  47  9,78899E+12                       BODY FOR LIFE  BILL PHILLIPS
#  47  48  9,78897E+12                            선의 나침반 1             현각
#  48  49  9,78892E+12                    TOEIC 터미네이터(R/C)            최종민
#  49  50  9,78894E+12                                 이슬람            이희수
#
#             출판사명       출간일        분야       정가
#  0         진명출판사  20000315      자기계발   \7,000
#  1            여백  20070630        소설   \7,500
#  2         생각의나무  20090420        소설   \8,800
#  3          황금가지  20090302     경제/경영  \12,000
#  4         바다출판사  20020504     시/에세이   \6,800
#  5          밝은세상  20000110        소설   \7,500
#  6          웅진닷컴  20000626     역사/문화  \12,000
#  7           동문선  20000620     시/에세이   \7,000
#  8          문학수첩  20091005        소설   \8,000
#  9           한문화  20010208      자기계발   \7,800
#  10           한언  20001106      자기계발   \8,900
#  11          넥서스  20010228       외국어  \21,500
#  12          넥서스  20010131       외국어  \29,500
#  13        문학사상사  20100720        소설  \15,000
#  14         사회평론  19990719       외국어   \9,800
#  15    프로메테우스출판사  20000601        소설   \7,500
#  16           이레  20010710     시/에세이   \9,000
#  17        실천문학사  20001026        소설   \8,000
#  18        문예출판사  19980810        소설   \8,000
#  19       21세기북스  20010228      자기계발   \8,500
#  20           한언  20001106      자기계발   \9,800
#  21         청년정신  20010910      자기계발  \12,000
#  22          김영사  20010810       외국어  \14,900
#  23        가나출판사  20001101   어린이(초등)   \8,500
#  24         오늘의책  20010428      자기계발  \10,000
#  25          열림원  19980410     시/에세이   \7,500
#  26        문학사상사  20010205        소설  \12,000
#  27           친구  19931201      자기계발   \9,000
#  28        문학세계사  20010720      자기계발   \8,200
#  29          푸른숲  20010824        여행   \8,800
#  30           이룸  20010430        소설   \7,500
#  31       창작과비평사  20010410        소설  \12,000
#  32  대원씨아이(사용안함)  20001201   어린이(초등)   \5,000
#  33         청림출판  20010130      자기계발  \12,000
#  34         문학동네  20121116        소설  \12,000
#  35           길벗  20000725       외국어  \12,000
#  36        책만드는집  20000810        소설   \6,500
#  37        학산문화사  20010115  유아(0~7세)   \8,000
#  38         열린책들  20080520        소설  \12,800
#  39           현재  20001001      자기계발   \8,000
#  40          디모데  20010225        종교   \6,500
#  41          김영사  20010115      자기계발  \12,900
#  42         밝은세상  20010905        소설   \9,500
#  43       21세기북스  20010215     경제/경영  \10,000
#  44          범우사  19990805     시/에세이   \8,000
#  45       창작과비평사  20070525        소설  \13,000
#  46    한국언론자료간행회  20010205        건강  \12,000
#  47          열림원  20010315        종교   \7,500
#  48        시사영어사  19990625       외국어  \15,000
#  49        청아출판사  20080410     역사/문화  \13,000  ,
#      순위         ISBN                                           도서명  \
#  0    1  9,78897E+12                         아홉살 인생(양장본 HardCover)
#  1    2  9,78897E+12                                        봉순이 언니
#  2    3   9,7889E+12                            그 많던 싱아는 누가 다 먹었을까
#  3    4  9,78897E+12                                       오페라의 유령
#  4    5  9,78894E+12                      괭이부리말 아이들(양장본 HardCover)
#  5    6  9,78897E+12                                         연탄길 1
#  6    7  9,78893E+12                                          뇌(상)
#  7    8  9,78898E+12                                  그러나 나는 살아가리라
#  8    9  9,78898E+12                                             화
#  9   10  9,78898E+12                            모랫말 아이들(어른을 위한 동화)
#  10  11  9,78899E+12                           화성에서 온 남자 금성에서 온 여자
#  11  12  9,78895E+12                                   TV동화 행복한 세상
#  12  13  9,78898E+12                                 누가 내 치즈를 옮겼을까
#  13  14    9,789E+12                                        창가의 토토
#  14  15  9,78897E+12                                  백범일지(보급판 2판)
#  15  16  9,78898E+12                    모리와 함께한 화요일(양장본 HardCover)
#  16  17  9,78893E+12  혼자만 잘 살믄 무슨 재민겨(개정증보판)(고집쟁이 농사꾼의 세상사는 이야기 1)
#  17  18  9,78898E+12                                  신경림의 시인을 찾아서
#  18  19  9,78898E+12                       이보영의 120분 영문법(TAPE3개포함)
#  19  20  9,78893E+12                                   달라이 라마의 행복론
#  20  21  9,78898E+12                                       위대한 개츠비
#  21  22  9,78899E+12                         무량수전 배흘림기둥에 기대서서(보급판)
#  22  23  9,78897E+12                          50 ENGLISH(TAPE2개포함)
#  23  24  9,78895E+12                                  NEXT SOCIETY
#  24  25  9,78898E+12                          이익훈 EYE OF THE TOEIC
#  25  26  9,78891E+12                        무소유(2판)(양장본 HardCover)
#  26  27  9,78899E+12                                        협상의 법칙
#  27  28  9,78899E+12                             내 영혼이 따뜻했던 날들(2판)
#  28  29  9,78893E+12                           호밀밭의 파수꾼(문예세계문학선 3)
#  29  30  9,78899E+12             블루데이북(The Blue Day Book Series 1)
#  30  31  9,78897E+12                                          괴물 1
#  31  32  9,78893E+12                                      단순하게 살아라
#  32  33  9,78899E+12                 그리스 로마 신화 10(트로이 트로이)(만화로 보는)
#  33  34   9,7889E+12                             이윤기의 그리스 로마 신화. 1
#  34  35  9,78897E+12                                    한비야의 중국견문록
#  35  36  9,78898E+12                                          등대지기
#  36  37  9,78899E+12                                       영원한 리베로
#  37  38  2,00889E+12                                   반지의 제왕(전6권)
#  38  39  9,78897E+12                            세계가 만일 100명의 마을이라면
#  39  40  9,78898E+12                               부자 아빠 가난한 아빠. 1
#  40  41  9,78897E+12                                        우동 한그릇
#  41  42  9,78898E+12                                          가시고기
#  42  43  9,78898E+12                          이익훈 EAR OF THE TOEIC
#  43  44  9,78897E+12                    지금 알고 있는 걸 그때도 알았더라면(잠언시집)
#  44  45  9,78897E+12                       상실의 시대(원제: 노르웨이의 숲)(3판)
#  45  46  9,78898E+12             셜록 홈즈 전집 1(주홍색 연구)(양장본 HardCover)
#  46  47  9,78897E+12                     토마토:토익점수마구올려주는토익(READING)
#  47  48  9,78894E+12                          환상동화집(양장본 HardCover)
#  48  49  9,78895E+12                                 열두살에 부자가 된 키라
#  49  50  9,78893E+12     TOEIC 답이 보인다(4판)(CASSETTE TAPE 3개 포함)(4판)
#
#               저자명       출판사명       출간일       분야       정가
#  0            위기철        청년사  20010126       소설   \8,000
#  1            공지영        푸른숲  19981130       소설   \6,000
#  2            박완서       웅진닷컴  19921001       소설   \7,000
#  3         가스통 르루      문학세계사  20031105       소설   \9,200
#  4            김중미     창작과비평사  20070820       소설  \13,800
#  5            이철환       삼진기획  20000801       소설   \7,500
#  6      베르나르 베르베르       열린책들  20020715       소설   \8,500
#  7            유용주          솔  20020907    시/에세이   \6,500
#  8            틱낫한      명진출판사  20110923    시/에세이   \8,900
#  9            황석영       문학동네  20010120       소설   \8,000
#  10         존 그레이         친구  19931201     자기계발   \9,000
#  11           박인식    샘터(샘터사)  20020305    시/에세이   \9,000
#  12        스펜서 존슨      진명출판사  20000315     자기계발   \7,000
#  13     구로야나기 테츠코  프로메테우스출판사  20000601       소설   \7,500
#  14            김구        돌베개  20020801    정치/사회   \9,500
#  15         미치 앨봄       세종서적  20020320    시/에세이   \8,500
#  16           전우익        현암사  20111110    시/에세이   \8,500
#  17           신경림       우리교육  19981020       인문   \8,000
#  18           이보영        넥서스  20020325      외국어  \15,000
#  19        달라이 라마        김영사  20011110    시/에세이  \12,800
#  20    F.스콧 피츠제럴드      책만드는집  20010827       소설   \8,000
#  21           최순우        학고재  20020305    역사/문화   \9,500
#  22            샘박     디자인하우스  20011115      외국어  \11,000
#  23        피터 드러커    한국경제신문사  20020710    경제/경영  \13,000
#  24           이익훈        넥서스  20011105      외국어  \18,500
#  25            법정        범우사  19990805    시/에세이   \8,000
#  26         허브 코헨       청년정신  20010910     자기계발  \12,000
#  27       포리스터 카터       아름드리  19980815       소설   \6,500
#  28     J. D. 샐린저      문예출판사  19980810       소설   \8,000
#  29  브래들리 트레버 그리브      바다출판사  20020504    시/에세이   \6,800
#  30           이외수      해냄출판사  20020810       소설   \8,500
#  31  베르너 티키 퀴스텐마허        김영사  20020917     자기계발  \12,800
#  32       토머스 볼핀치      가나출판사  20020425  어린이(초등)   \8,500
#  33           이윤기       웅진닷컴  20000626    역사/문화  \12,000
#  34           한비야        푸른숲  20010824       여행   \8,800
#  35           조창인       밝은세상  20010905       소설   \9,500
#  36           홍명보       은행나무  20020525    시/에세이   \8,900
#  37      J.R.R.톨킨       황금가지  20011201       소설  \45,000
#  38       이케다 가요코      국일출판사  20020310    시/에세이   \6,800
#  39      로버트 기요사키       황금가지  20090302    경제/경영  \12,000
#  40        구리 료헤이        청조사  19890701       소설   \7,500
#  41           조창인       밝은세상  20000110       소설   \7,500
#  42           이익훈        넥서스  20010707      외국어  \21,500
#  43           류시화        열림원  19980410    시/에세이   \7,500
#  44      무라카미 하루키      문학사상사  20100720       소설  \15,000
#  45      아서 코난 도일       황금가지  20020205       소설   \8,000
#  46           오혜정       능률교육  20020107      외국어  \17,000
#  47        헤르만 헤세        민음사  20141021       소설  \15,000
#  48         보도 섀퍼        을파소  20010810  어린이(초등)  \12,000
#  49           김대균        김영사  20020125      외국어  \15,900  ,
#      순위         ISBN                                           도서명  \
#  0    1  9,78893E+12                                            나무
#  1    2  9,78899E+12                                      톨스토이 단편선
#  2    3  9,78897E+12                                     파페포포 메모리즈
#  3    4  9,78897E+12                                        야생초 편지
#  4    5  9,78898E+12                                             화
#  5    6  9,78899E+12                                       한국의 부자들
#  6    7  9,78895E+12                                    설득의 심리학. 1
#  7    8  9,78894E+12                                    지상에 숟가락 하나
#  8    9  9,78897E+12                                     내 생애의 아이들
#  9   10  9,78895E+12                                칭찬은 고래도 춤추게 한다
#  10  11  9,78898E+12                    모리와 함께한 화요일(양장본 HardCover)
#  11  12  9,78898E+12                            해리포터와 불사조기사단 제5권 1
#  12  13  9,78895E+12                              달님은 알지요(일공일삼 27)
#  13  14  9,78897E+12                               냉정과 열정사이(ROSSO)
#  14  15  9,78897E+12                         아홉살 인생(양장본 HardCover)
#  15  16  9,78894E+12                                포엠툰(POEM TOON)
#  16  17  9,78898E+12                          이익훈 EYE OF THE TOEIC
#  17  18  9,78897E+12                     토마토:토익점수마구올려주는토익(READING)
#  18  19  9,78896E+12                                바보들은 항상 결심만 한다
#  19  20  9,78897E+12                               가방 들어 주는 아이(2판)
#  20  21  9,78897E+12                              고기잡이는 갈대를 꺾지 않는다
#  21  22  9,78898E+12                                          공부기술
#  22  23  9,78897E+12                                   나의 라임 오렌지나무
#  23  24  9,78899E+12                                        메모의 기술
#  24  25  9,78894E+12                    한시 이야기(정민 선생님이 들려주는)(진경문고)
#  25  26    9,789E+12                                        창가의 토토
#  26  27  9,78893E+12  혼자만 잘 살믄 무슨 재민겨(개정증보판)(고집쟁이 농사꾼의 세상사는 이야기 1)
#  27  28  9,78899E+12                                   물은 답을 알고 있다
#  28  29  9,78898E+12                                   폰더씨의 위대한 하루
#  29  30   9,7889E+12                                     살아있는 역사 1
#  30  31  9,78893E+12                       마당깊은 집(문학과지성 소설 명작선 15)
#  31  32  9,78893E+12                                      단순하게 살아라
#  32  33  9,78897E+12                                    해변의 카프카(상)
#  33  34  9,78899E+12                            아침형 인간(인생을 두배로 사는)
#  34  35  9,78899E+12                           화성에서 온 남자 금성에서 온 여자
#  35  36  9,78896E+12                                           완두콩
#  36  37  9,78898E+12                          이익훈 EAR OF THE TOEIC
#  37  38  9,78899E+12                     그리스 로마 신화 14(트로이)(만화로 보는)
#  38  39  9,78895E+12                                 열두살에 부자가 된 키라
#  39  40  9,78898E+12                                 누가 내 치즈를 옮겼을까
#  40  41  9,78893E+12                                          삼국유사
#  41  42  9,78896E+12                                       지선아 사랑해
#  42  43  9,78895E+12                             30부터 준비하는 당당한 내인생
#  43  44    9,789E+12                               난장이가 쏘아 올린 작은 공
#  44  45  9,78899E+12                             내 영혼이 따뜻했던 날들(2판)
#  45  46  9,78898E+12                      이보영의 120분 영어회화(TAPE3개포함)
#  46  47  9,78897E+12                                     곽재구의 포구기행
#  47  48  9,78899E+12                                            운명
#  48  49  9,78899E+12                 강아지똥(민들레그림책 1)(양장본 HardCover)
#  49  50  9,78899E+12                                   그 놈은 멋있었다 1
#
#               저자명       출판사명       출간일        분야       정가
#  0      베르나르 베르베르       열린책들  20030630        소설   \8,800
#  1       L.N.톨스토이        인디북  20030307        소설   \8,500
#  2            심승현      홍익출판사  20021023        만화   \7,500
#  3            황대권         도솔  20021001     시/에세이   \8,500
#  4            틱낫한      명진출판사  20110923     시/에세이   \8,900
#  5            한상복     위즈덤하우스  20030205     경제/경영  \11,000
#  6       로버트 치알디니     21세기북스  20020930      자기계발  \12,000
#  7            현기영      실천문학사  19990315        소설   \8,000
#  8        가브리엘 루아       현대문학  20030708        소설  \12,000
#  9         켄 블랜차드     21세기북스  20021228      자기계발  \10,000
#  10         미치 앨봄       세종서적  20020320     시/에세이   \8,500
#  11      조앤 K. 롤링       문학수첩  20070228        소설   \8,500
#  12           김향이        비룡소  19941001   어린이(초등)   \5,000
#  13       에쿠니 가오리      소담출판사  20001120        소설  \12,000
#  14           위기철        청년사  20010126        소설   \8,000
#  15           정헌재         청하  20021230        만화   \9,000
#  16           이익훈        넥서스  20011105       외국어  \18,500
#  17           오혜정       능률교육  20020107       외국어  \17,000
#  18         팻 맥라건         예문  20021125      자기계발  \10,000
#  19           고정욱        사계절  20030505   어린이(초등)   \6,000
#  20           김주영        문이당  20010416        소설   \8,000
#  21           조승연     중앙 M&B  20021127   중/고등참고서   \8,000
#  22    J.M.바스콘셀로스         동녘  20030905        소설   \7,000
#  23        사카토 켄지       해바라기  20030527      자기계발   \7,800
#  24            정민         보림  20020702   어린이(초등)  \13,000
#  25     구로야나기 테츠코  프로메테우스출판사  20000601        소설   \7,500
#  26           전우익        현암사  20111110     시/에세이   \8,500
#  27       에모토 마사루     나무심는사람  20020820        과학   \8,000
#  28       앤디 앤드루스       세종서적  20030725     시/에세이   \9,500
#  29    힐러리 로댐 클린턴       웅진닷컴  20030619     시/에세이  \12,000
#  30           김원일     문학과지성사  19910201        소설  \11,000
#  31  베르너 티키 퀴스텐마허        김영사  20020917      자기계발  \12,800
#  32      무라카미 하루키      문학사상사  20030725        소설   \9,000
#  33       사이쇼 히로시      한스미디어  20031006      자기계발  \10,000
#  34         존 그레이         친구  20021210      자기계발  \10,000
#  35           정헌재      바다출판사  20030702        만화   \9,000
#  36           이익훈        넥서스  20010707       외국어  \21,500
#  37       토머스 볼핀치      가나출판사  20030101   어린이(초등)   \8,500
#  38         보도 섀퍼        을파소  20010810   어린이(초등)  \12,000
#  39        스펜서 존슨      진명출판사  20000315      자기계발   \7,000
#  40            일연      을유문화사  20021115     역사/문화   \9,000
#  41           이지선         이레  20030507     시/에세이   \9,000
#  42           송양민     21세기북스  20021216     경제/경영  \12,000
#  43           조세희       이성과힘  20000710        소설  \11,000
#  44       포리스터 카터       아름드리  19980815        소설   \6,500
#  45           이보영        넥서스  20030115       외국어  \15,000
#  46           곽재구        열림원  20131204        여행  \13,000
#  47       임레 케르테스       다른우리  20021205        소설   \9,500
#  48           권정생      길벗어린이  20140418  유아(0~7세)  \12,000
#  49           귀여니         황매  20030315        소설   \9,000  ,
#      순위         ISBN                                   도서명         저자명  \
#  0    1  9,78898E+12                                  연금술사     파울로 코엘료
#  1    2  9,78896E+12                             다 빈치 코드 1       댄 브라운
#  2    3  9,78896E+12                                    선물      스펜서 존슨
#  3    4  9,78895E+12                            설득의 심리학. 1    로버트 치알디니
#  4    5  9,78899E+12                    아침형 인간(인생을 두배로 사는)     사이쇼 히로시
#  5    6  9,78893E+12                                    나무   베르나르 베르베르
#  6    7  9,78896E+12                             그 남자 그 여자         이미나
#  7    8  9,78898E+12                          칼의 노래 1(개정판)          김훈
#  8    9    9,789E+12                           꽃으로도 때리지 말라         김혜자
#  9   10  9,78899E+12                      세상의 중심에서 사랑을 외치다    카타야마 쿄이치
#  10  11  9,78897E+12                               10년후 한국         공병호
#  11  12  9,78899E+12                                메모의 기술      사카토 켄지
#  12  13    9,789E+12                                    용서      달라이 라마
#  13  14  9,78895E+12                        칭찬은 고래도 춤추게 한다      켄 블랜차드
#  14  15  9,78893E+12                         2000원으로 밥상차리기         김용환
#  15  16  9,78898E+12                    11분(양장본 HardCover)     파울로 코엘료
#  16  17  9,78898E+12                  이익훈 EYE OF THE TOEIC         이익훈
#  17  18  9,78899E+12                        나를 변화시키는 좋은 습관         한창욱
#  18  19  9,78897E+12             토마토:토익점수마구올려주는토익(READING)         오혜정
#  19  20  9,78896E+12                                황진이. 1         전경린
#  20  21  9,78895E+12                             홀로 사는 즐거움          법정
#  21  22  9,78898E+12                           폰더씨의 위대한 하루     앤디 앤드루스
#  22  23  9,78897E+12                       냉정과 열정사이(ROSSO)     에쿠니 가오리
#  23  24  9,78895E+12                              마법천자문. 1    스튜디오 시리얼
#  24  25  9,78894E+12                             목적이 이끄는 삶        릭 워렌
#  25  26    9,789E+12                    평생 성적 초등 4학년에 결정된다         김강일
#  26  27  9,78896E+12     집 없어도 땅은 사라(돈앞에 당당한 경제자유인 프로젝트 3)         김혜경
#  27  28  9,78898E+12          베로니카 죽기로 결심하다(양장본 HardCover)     파울로 코엘료
#  28  29  9,78898E+12                  이익훈 EAR OF THE TOEIC         이익훈
#  29  30  9,78898E+12              이보영의 120분 영어회화(TAPE3개포함)         이보영
#  30  31  9,78898E+12            모리와 함께한 화요일(양장본 HardCover)       미치 앨봄
#  31  32  9,78898E+12                      대한민국에서 장남으로 살아가기         윤영무
#  32  33  9,78893E+12                          공부 9단 오기 10단         박원희
#  33  34  9,78897E+12           토마토:토익점수마구올려주는토익(LISTENING)         오혜정
#  34  35  9,78898E+12                             진주 귀고리 소녀   트레이시 슈발리에
#  35  36  9,78899E+12                            엄마와 딸(전2권)       폴린 페리
#  36  37  9,78897E+12                             파페포포 메모리즈         심승현
#  37  38  9,78899E+12                               미쳐야 미친다          정민
#  38  39  9,78897E+12           나의 라임 오렌지 나무(양장본 HardCover)  J.M.바스콘셀로스
#  39  40  9,78893E+12  21세기 먼나라 이웃나라 10 (미국 1:미국인 편) (올컬러판)         이원복
#  40  41  9,78897E+12               상실의 시대(원제: 노르웨이의 숲)(3판)    무라카미 하루키
#  41  42  9,78897E+12                            해변의 카프카(상)    무라카미 하루키
#  42  43  9,78899E+12                   화성에서 온 남자 금성에서 온 여자       존 그레이
#  43  44  9,78898E+12               이보영의 120분 영문법(TAPE3개포함)         이보영
#  44  45  9,78897E+12                           울 준비는 되어 있다     에쿠니 가오리
#  45  46  9,78897E+12                               그 남자네 집         박완서
#  46  47  9,78894E+12                   체 게바라 평전(역사인물찾기 10)      장 코르미에
#  47  48  9,78897E+12                    박경림 영어 성공기(CD1장포함)         박경림
#  48  49    9,789E+12                                연인 서태후        펄S.벅
#  49  50  9,78896E+12                              따뜻한 카리스마         이종선
#
#           출판사명       출간일       분야       정가
#  0        문학동네  20181205       소설   \9,500
#  1         북스캔  20070611       소설   \7,800
#  2    랜덤하우스코리아  20031215     자기계발   \8,500
#  3      21세기북스  20020930     자기계발  \12,000
#  4       한스미디어  20031006     자기계발  \10,000
#  5        열린책들  20030630       소설   \8,800
#  6       중앙M&B  20031217    시/에세이   \9,500
#  7       생각의나무  20031208       소설   \7,500
#  8       오래된미래  20081028    시/에세이  \12,500
#  9        지식여행  20051010       소설   \5,900
#  10      해냄출판사  20040607    경제/경영  \10,000
#  11       해바라기  20030527     자기계발   \7,800
#  12      오래된미래  20100615    시/에세이  \12,000
#  13     21세기북스  20021228     자기계발  \10,000
#  14       영진닷컴  20031115       요리   \8,800
#  15       문학동네  20140127       소설  \12,000
#  16        넥서스  20011105      외국어  \18,500
#  17       새론북스  20040110     자기계발   \8,500
#  18       능률교육  20020107      외국어  \17,000
#  19         이룸  20040805       소설   \9,000
#  20    샘터(샘터사)  20040501    시/에세이   \9,800
#  21       세종서적  20030725    시/에세이   \9,500
#  22      소담출판사  20001120       소설  \12,000
#  23   북이십일 아울북  20031114  어린이(초등)   \8,800
#  24        디모데  20030125       종교  \12,000
#  25      예담프렌드  20040715    가정/육아   \9,800
#  26  국일증권경제연구소  20040605    경제/경영  \12,800
#  27       문학동네  20140410       소설  \11,500
#  28        넥서스  20010707      외국어  \21,500
#  29        넥서스  20030115      외국어  \15,000
#  30       세종서적  20020320    시/에세이   \8,500
#  31      명진출판사  20040612    시/에세이   \9,500
#  32        김영사  20040724  중/고등참고서   \9,900
#  33       능률교육  20020107      외국어  \16,000
#  34          강  20030825       소설   \9,500
#  35         큰나  20040710    시/에세이   \9,000
#  36      홍익출판사  20021023       만화   \7,500
#  37       푸른역사  20040403    역사/문화  \11,900
#  38         동녘  20021210       소설   \7,500
#  39        김영사  20100710  어린이(초등)  \11,900
#  40      문학사상사  20100720       소설  \15,000
#  41      문학사상사  20030725       소설   \9,000
#  42         친구  20021210     자기계발  \10,000
#  43        넥서스  20020325      외국어  \15,000
#  44      소담출판사  20040503       소설   \9,000
#  45       현대문학  20041023       소설   \9,000
#  46      실천문학사  20000305    정치/사회  \12,000
#  47     디자인하우스  20040615      외국어  \12,000
#  48         길산  20030630       소설  \22,000
#  49   랜덤하우스코리아  20040716     자기계발  \12,000  ,
#       순위         ISBN                                                도서명  \
#  0     1  9,78899E+12                               살아 있는 동안 꼭 해야 할 49가지
#  1     2  9,78896E+12                                          다 빈치 코드 1
#  2     3  9,78895E+12                                     모모(비룡소 걸작선 13)
#  3     4  9,78898E+12                                               연금술사
#  4     5  9,78897E+12                              블루오션전략(양장본 HardCover)
#  5     6    9,789E+12                               사랑하라 한번도 상처받지 않은 것처럼
#  6     7  9,78899E+12                                     해커스 토익 READING
#  7     8  9,78895E+12                                      2010 대한민국 트렌드
#  8     9  9,78898E+12                                   해리포터와 혼혈왕자 제6권 1
#  9    10  9,78895E+12                                         설득의 심리학. 1
#  10   11  9,78895E+12                                              긍정의 힘
#  11   12  9,78896E+12                               여자의 모든 인생은 20대에 결정된다
#  12   13  9,78897E+12                                        지도 밖으로 행군하라
#  13   14  9,78898E+12                       베로니카 죽기로 결심하다(양장본 HardCover)
#  14   15  9,78896E+12                                               공중그네
#  15   16  9,78899E+12                                     해커스 토익(CD1장포함)
#  16   17  9,78897E+12                                             어둠의 저편
#  17   18  9,78896E+12                                                 선물
#  18   19  9,78897E+12                                  미실(제1회 세계문학상 당선작)
#  19   20  9,78894E+12                                          목적이 이끄는 삶
#  20   21  9,78898E+12                                       천국에서 만난 다섯사람
#  21   22  9,78898E+12                               오 자히르(양장본 HardCover)
#  22   23  9,78899E+12                                   세상의 중심에서 사랑을 외치다
#  23   24  9,78897E+12                                            그 남자네 집
#  24   25  9,78896E+12                             아이 안에 숨어 있는 두뇌의 힘을 키워라
#  25   26  9,78893E+12               21세기 먼나라 이웃나라 12 (미국 3:대통령 편) (올컬러판)
#  26   27  9,78897E+12                          사소한 것에 목숨 걸지 마라(습관 바꾸기 편)
#  27   28  9,78897E+12                                        우리들의 행복한 시간
#  28   29  9,78898E+12                                          진주 귀고리 소녀
#  29   30  9,78898E+12                                         미운오리새끼의 출근
#  ..  ...          ...                                                ...
#  70   71  9,78897E+12                                            10년후 한국
#  71   72  9,78899E+12                                        친구야 공부 왜 하니
#  72   73  9,78894E+12                    곤충세계에서 살아남기. 1(서바이벌 만화 과학상식 13)
#  73   74  9,78897E+12                                                 강의
#  74   75    9,789E+12                                     기적은 당신 안에 있습니다
#  75   76  9,78894E+12                                체 게바라 평전(역사인물찾기 10)
#  76   77  9,78898E+12                                 11분(양장본 HardCover)
#  77   78  9,78899E+12                                     나를 변화시키는 좋은 습관
#  78   79  9,78896E+12                                             황진이. 1
#  79   80  9,78895E+12                                         문학의 숲을 거닐다
#  80   81  9,78893E+12                                                 나무
#  81   82  9,78895E+12                           메이플 스토리 오프라인 RPG. 11(코믹)
#  82   83  9,78895E+12                  비타민 동화(선생님이 들려주는 45가지 가슴 뭉클한 이야기)
#  83   84  9,78894E+12                              하늘에 속한 사람(믿음의 글들 214)
#  84   85  9,78899E+12                                            미쳐야 미친다
#  85   86  9,78898E+12  이익훈 EAR OF THE TOEIC (L/C) (CD-ROM 1장 포함) (200...
#  86   87  9,78896E+12                                           자기 설득 파워
#  87   88  9,78897E+12                   토마토:토익점수마구올려주는토익(LISTENING)(2/E)
#  88   89  9,78896E+12                                           따뜻한 카리스마
#  89   90  9,78893E+12                                     500원으로 밑반찬 만들기
#  90   91  9,78896E+12                 100가지 과학 1000가지 상식(초등학생이 가장 궁금해하는)
#  91   92  9,78899E+12                                         마흔으로 산다는 것
#  92   93    9,789E+12                                             연인 서태후
#  93   94  9,78898E+12                           이보영의 120분 영어회화(TAPE3개포함)
#  94   95  9,78899E+12                                      왜 나는 너를 사랑하는가
#  95   96  9,78898E+12                                            비밀과 거짓말
#  96   97  9,78899E+12              그리스 로마 신화. 19: 오디세우스의 복수(만화로 보는)(개정판)
#  97   98  9,78894E+12                                        잭 웰치 위대한 승리
#  98   99  9,78899E+12                  해커스 리딩 스타트(Hackers Reading Start)
#  99  100    9,789E+12                                 평생 성적 초등 4학년에 결정된다
#
#            저자명      출판사명       출간일       분야       정가
#  0         탄줘잉    위즈덤하우스  20041220     자기계발   \8,800
#  1       댄 브라운       북스캔  20070611       소설   \7,800
#  2      미하엘 엔데       비룡소  20091020       소설  \12,000
#  3     파울로 코엘료      문학동네  20181205       소설   \9,500
#  4         김위찬      교보문고  20050407    경제/경영  \17,000
#  5         류시화     오래된미래  20081024    시/에세이   \9,500
#  6   David Cho  해커스어학연구소  20050102      외국어  \18,800
#  7     LG경제연구원   한국경제신문사  20050115    경제/경영  \12,000
#  8    조앤 K. 롤링      문학수첩  20051101       소설   \8,500
#  9    로버트 치알디니    21세기북스  20020930     자기계발  \12,000
#  10     조엘 오스틴       두란노  20050511       종교  \12,000
#  11        남인숙  랜덤하우스코리아  20040710     자기계발   \8,500
#  12        한비야       푸른숲  20050908       여행  \12,000
#  13    파울로 코엘료      문학동네  20140410       소설  \11,500
#  14    오쿠다 히데오      은행나무  20150615       소설  \12,000
#  15  David Cho  해커스어학연구소  20041202      외국어  \18,900
#  16   무라카미 하루키      문학사상  20050526       소설  \13,800
#  17     스펜서 존슨  랜덤하우스코리아  20031215     자기계발   \8,500
#  18        김별아       문이당  20050305       소설   \9,500
#  19       릭 워렌       디모데  20030125       종교  \12,000
#  20      미치 앨봄      세종서적  20050320       소설   \9,000
#  21    파울로 코엘료      문학동네  20131224       소설  \13,800
#  22   카타야마 쿄이치      지식여행  20051010       소설   \5,900
#  23        박완서      현대문학  20041023       소설   \9,000
#  24        이승헌       한문화  20050221    가정/육아   \9,800
#  25        이원복       김영사  20050120  어린이(초등)  \11,900
#  26     리처드 칼슨        도솔  20040802     자기계발   \7,800
#  27        공지영       푸른숲  20050417       소설   \9,500
#  28  트레이시 슈발리에         강  20030825       소설   \9,500
#  29     메트 노가드     생각의나무  20050402     자기계발  \10,000
#  ..        ...       ...       ...      ...      ...
#  70        공병호     해냄출판사  20040607    경제/경영  \10,000
#  71        곽기우        큰나  20050228  어린이(초등)   \8,500
#  72        코믹컴      아이세움  20050728  어린이(초등)   \9,000
#  73        신영복       돌베개  20041211       인문  \18,000
#  74        이승복     황금나침반  20090324    시/에세이  \13,000
#  75     장 코르미에     실천문학사  20000305    정치/사회  \12,000
#  76    파울로 코엘료      문학동네  20140127       소설  \12,000
#  77        한창욱      새론북스  20040110     자기계발   \8,500
#  78        전경린        이룸  20040805       소설   \9,000
#  79        장영희   샘터(샘터사)  20050315    시/에세이  \12,000
#  80  베르나르 베르베르      열린책들  20030630       소설   \8,800
#  81        송도수     서울문화사  20050810  어린이(초등)   \8,500
#  82        박성철        계림  20031110  어린이(초등)   \8,500
#  83     폴 해터웨이       홍성사  20040730       종교  \13,000
#  84         정민      푸른역사  20040403    역사/문화  \11,900
#  85        이익훈       넥서스  20050223      외국어  \21,500
#  86        백지연  랜덤하우스코리아  20050220     자기계발   \9,800
#  87        오혜정      능률교육  20041005      외국어  \20,000
#  88        이종선  랜덤하우스코리아  20040716     자기계발  \12,000
#  89        신진원      영진닷컴  20041025       요리   \8,800
#  90        이광렬     세상모든책  20030805  어린이(초등)  \11,000
#  91        전경일      다산북스  20050311     자기계발  \10,000
#  92       펄S.벅        길산  20030630       소설  \22,000
#  93        이보영       넥서스  20030115      외국어  \15,000
#  94    알랭 드 보통       청미래  20020715       소설   \8,500
#  95        은희경      문학동네  20050129       소설   \9,000
#  96    토머스 불핀치     가나출판사  20110701  어린이(초등)  \10,500
#  97       잭 웰치      청림출판  20050505     자기계발  \16,800
#  98  David Cho  해커스어학연구소  20030702      외국어  \14,900
#  99        김강일     예담프렌드  20040715    가정/육아   \9,800
#
#  [100 rows x 8 columns],
#       순위         ISBN                                                도서명  \
#  0     1  9,78895E+12                                           마시멜로 이야기
#  1     2  9,78897E+12                                        우리들의 행복한 시간
#  2     3  9,78898E+12                                    끌리는 사람은 1%가 다르다
#  3     4  9,78899E+12                              해커스 토익 Reading(해설집포함)
#  4     5  9,78896E+12                                              인생 수업
#  5     6  9,78899E+12                                                 배려
#  6     7  9,78894E+12                                 부의 미래(앨빈 토플러)(반양장)
#  7     8  9,78895E+12                                              긍정의 힘
#  8     9    9,789E+12                                    살아 있는 것은 다 행복하라
#  9    10  9,78899E+12                                   해커스 토익 Listening
#  10   11   9,7889E+12                                         경제학 콘서트. 1
#  11   12  9,78897E+12                사랑 후에 오는 것들(공지영)(중판)(양장본 HardCover)
#  12   13  9,78895E+12                                     악마는 프라다를 입는다 1
#  13   14  9,78897E+12                                             여자생활백서
#  14   15  9,78896E+12                                          다 빈치 코드 1
#  15   16  9,78897E+12             토마토 베이직: READING(토익이 가벼워지는)(단어암기장1권포함)
#  16   17  9,78896E+12                               여자의 모든 인생은 20대에 결정된다
#  17   18  9,78893E+12                                  향수(양장본 HardCover)
#  18   19   9,7889E+12                                                  핑
#  19   20  9,78897E+12                                        지도 밖으로 행군하라
#  20   21  9,78895E+12                                     모모(비룡소 걸작선 13)
#  21   22  9,78895E+12                                          행복한 이기주의자
#  22   23  9,78899E+12                                         한국의 젊은 부자들
#  23   24  9,78896E+12                                               공중그네
#  24   25  9,78898E+12                                               연금술사
#  25   26  9,78897E+12                            아내가 결혼했다(제2회 세계문학상 당선작)
#  26   27   9,7889E+12                                       시골의사의 부자 경제학
#  27   28  9,78897E+12                사랑 후에 오는 것들(츠지 히토나리)(양장본 HardCover)
#  28   29  9,78894E+12                                  오만과 편견(세계문학전집 88)
#  29   30  9,78895E+12                                         설득의 심리학. 1
#  ..  ...          ...                                                ...
#  70   71  9,78896E+12                                                 선물
#  71   72  9,78899E+12                                      왜 나는 너를 사랑하는가
#  72   73  9,78896E+12                        우리는 사랑일까(2판)(양장본 HardCover)
#  73   74  9,78895E+12                                 10년 법칙(명품 인생을 만드는)
#  74   75  9,78898E+12                                        폰더씨의 위대한 하루
#  75   76  9,78899E+12                        배려(어린이를 위한)(어린이 자기계발 동화 01)
#  76   77  9,78896E+12                                           천사와 악마 1
#  77   78  9,78897E+12                                      부자의 생각 빈자의 생각
#  78   79  9,78896E+12                                        On the Road
#  79   80  9,78897E+12                     밤이여 나뉘어라(제30회 이상문학상 작품집 2006년)
#  80   81  9,78899E+12                                   내 인생에 힘이 되어준 한마디
#  81   82  9,78899E+12  만화 과학 교과서. 1: 지구과학, 물리(중학생이 되기 전에 꼭 읽어야)(되기 전에...
#  82   83  9,78896E+12                                          디셉션 포인트 1
#  83   84  9,78893E+12                                      2000원으로 밥상차리기
#  84   85  9,78899E+12                                      내 영단어장을 공개합니다
#  85   86  9,78895E+12                 구름빵(5판)(마음씨앗 그림책 2)(양장본 HardCover)
#  86   87  9,78895E+12                                           공병호의 초콜릿
#  87   88  9,78897E+12                                           반짝반짝 빛나는
#  88   89  9,78899E+12                                TRY AGAIN(TAPE4개포함)
#  89   90  9,78899E+12                                          부모와 아이 사이
#  90   91  9,78898E+12                                               황금사과
#  91   92  9,78898E+12                     독학 일본어 첫걸음(혼자서도 너무 쉬운)(CD1장포함)
#  92   93  9,78897E+12                          사소한 것에 목숨 걸지 마라(습관 바꾸기 편)
#  93   94  9,78897E+12                            상실의 시대(원제: 노르웨이의 숲)(3판)
#  94   95  9,78894E+12                                          레벌루션 NO.3
#  95   96  9,78895E+12                                       블링크(첫 2초의 힘)
#  96   97  9,78899E+12                        화성에서 온 남자 금성에서 온 여자(개정판 2판)
#  97   98  9,78895E+12                           메이플 스토리 오프라인 RPG. 14(코믹)
#  98   99  9,78899E+12                 HACKERS WRITING START(해커스 라이팅 스타트)
#  99  100  9,78893E+12                             책 먹는 여우(양장본 HardCover)
#
#               저자명      출판사명       출간일        분야       정가
#  0      호아킴 데 포사다   한국경제신문사  20090120      자기계발  \10,000
#  1            공지영       푸른숲  20050417        소설   \9,500
#  2            이민규     더난출판사  20051117      자기계발  \12,000
#  3      David Cho  해커스어학연구소  20080315       외국어  \18,800
#  4   엘리자베스 퀴블러 로스        이레  20140520     시/에세이  \13,800
#  5            한상복    위즈덤하우스  20060110      자기계발  \10,000
#  6         앨빈 토플러      청림출판  20060818     경제/경영  \19,800
#  7         조엘 오스틴       두란노  20050511        종교  \12,000
#  8             법정     조화로운삶  20060215     시/에세이   \9,800
#  9      David Cho  해커스어학연구소  20071210       외국어  \18,800
#  10         팀 하포드     웅진씽크빅  20060205     경제/경영  \13,000
#  11           공지영     소담출판사  20130208        소설  \12,000
#  12      로렌 와이스버거      문학동네  20060511        소설  \10,000
#  13           안은영     해냄출판사  20060410      자기계발  \13,800
#  14         댄 브라운       북스캔  20070611        소설   \7,800
#  15           김지연      능률교육  20051020       외국어   \9,900
#  16           남인숙  랜덤하우스코리아  20040710      자기계발   \8,500
#  17     파트리크 쥐스킨트      열린책들  20080520        소설  \12,800
#  18  스튜어트 에이버리 골드      웅진윙스  20060111      자기계발   \9,800
#  19           한비야       푸른숲  20050908        여행  \12,000
#  20        미하엘 엔데       비룡소  20091020        소설  \12,000
#  21        웨인 다이어    21세기북스  20060425      자기계발  \10,000
#  22           박용석      토네이도  20060313     경제/경영  \12,000
#  23       오쿠다 히데오      은행나무  20150615        소설  \12,000
#  24       파울로 코엘료      문학동네  20181205        소설   \9,500
#  25           박현욱       문이당  20060315        소설   \9,800
#  26           박경철      리더스북  20060628     경제/경영  \12,000
#  27       츠지 히토나리     소담출판사  20130208        소설  \12,000
#  28        제인 오스틴       민음사  20090120        소설  \11,000
#  29      로버트 치알디니    21세기북스  20020930      자기계발  \12,000
#  ..           ...       ...       ...       ...      ...
#  70        스펜서 존슨  랜덤하우스코리아  20031215      자기계발   \8,500
#  71       알랭 드 보통       청미래  20020715        소설   \8,500
#  72       알랭 드 보통      은행나무  20110310        소설  \12,500
#  73           공병호    21세기북스  20060220      자기계발  \10,000
#  74       앤디 앤드루스      세종서적  20030725     시/에세이   \9,500
#  75           전지은    위즈덤하우스  20060515   어린이(초등)   \8,500
#  76         댄 브라운       북스캔  20040930        소설   \8,800
#  77           공병호     해냄출판사  20051230      자기계발  \12,800
#  78            박준  넥서스BOOKS  20060610        여행  \13,000
#  79           정미경      문학사상  20141229        소설  \12,000
#  80           정호승        비채  20060308     시/에세이  \10,500
#  81           고윤곤       스콜라  20060127   어린이(초등)  \11,000
#  82         댄 브라운       북스캔  20060505        소설   \8,800
#  83           김용환      영진닷컴  20031115        요리   \8,800
#  84       오자키 데쓰오        이젠  20050215       외국어  \10,000
#  85           백희나      한솔수북  20070205  유아(0~7세)  \11,000
#  86           공병호    21세기북스  20060705      자기계발  \10,000
#  87       에쿠니 가오리     소담출판사  20020218        소설  \12,000
#  88           이근철     길벗이지톡  20040530       외국어  \19,800
#  89      하임 G.기너트       양철북  20030816        인문  \11,000
#  90       캐시 애론 슨     명진출판사  20060817      자기계발  \10,000
#  91           정선영       넥서스  20050110       외국어  \13,500
#  92        리처드 칼슨        도솔  20040802      자기계발   \7,800
#  93      무라카미 하루키     문학사상사  20100720        소설  \15,000
#  94      가네시로 가즈키      북폴리오  20060210        소설   \8,500
#  95       말콤 글래드웰    21세기북스  20051120      자기계발  \13,000
#  96         존 그레이     동녘라이프  20080825      자기계발  \12,000
#  97           송도수     서울문화사  20060125   어린이(초등)   \8,500
#  98     David Cho  해커스어학연구소  20030624       외국어  \16,900
# ...
#  11    12  9788965132288                                         어떻게 살 것인가
#  12    13  9788954645614                                           오직 두 사람
#  13    14  9788959139309                어쩌면 별들이 너의 슬픔을 가져갈지도 몰라(감성치유 라이팅북)
#  14    15  9788962805901                                제4차 산업혁명(클라우스 슈밥의)
#  15    16  9788994120966                                지적 대화를 위한 넓고 얕은 지식
#  16    17  9788996991342                   미움받을 용기(교보문고 단독 스페셜 에디션)(리커버:K)
#  17    18  9788934977841                                            호모 데우스
#  18    19  9788932918372                               잠. 1(양장본 HardCover)
#  19    20  9788934972464                                              사피엔스
#  20    21  9791160486735                                           완벽한 공부법
#  21    22  9791186805398                                          그릿(Grit)
#  22    23  9788965421832                          해커스 토익 기출 보카(TOEIC VOCA)
#  23    24  9791186274156                                        약간의 거리를 둔다
#  24    25  9791159030987                                 하늘과 바람과 별과 시(초판본)
#  25    26  9791133440054                                           너의 이름은.
#  26    27  9788936433598                                             채식주의자
#  27    28  9788990982674                                            기린의 날개
#  28    29  9791186560433                            명견만리: 정치, 생애, 직업, 탐구 편
#  29    30  9788960863132                                     영어책 한 권 외워봤니?
#  ..   ...            ...                                               ...
#  170  171  9788996588733                                정재승의 과학 콘서트(개정증보판)
#  171  172  9788936434267                                아몬드(양장본 HardCover)
#  172  173  9788952777638                        부동산 투자의 정석(10년 후에도 변하지 않을)
#  173  174  9788947541473                                  나는 마트 대신 부동산에 간다
#  174  175  9788950968670                            마법천자문. 38: 지탱해라! 지탱할 지
#  175  176  9788965962281                                           힐빌리의 노래
#  176  177  9788927807025                                           어쩌다 한국인
#  177  178  9791195363063                                      스페셜솔져 코믹스. 1
#  178  179  9788901219943                                         신경 끄기의 기술
#  179  180  9788963708386                        예감은 틀리지 않는다(양장본 HardCover)
#  180  181  9788984076266                                         부자언니 부자연습
#  181  182  9788937889714        추리 천재 엉덩이 탐정. 3: 불멸의 절도단 사건(양장본 HardCover)
#  182  183  9788965421733  해커스 토익 중급 리딩(Hackers TOEIC Reading)(신토익 Edition)
#  183  184  9791157060849                                       경제, 알아야 바꾼다
#  184  185  9791159996665                              BIGVOCA core(빅보카 코어)
#  185  186  9788998114114                          시원스쿨 기초 영어법(개정판)(CD1장포함)
#  186  187  9788952772978                                            유아 식판식
#  187  188  9791195716937                                          나쁜 페미니스트
#  188  189  9791133437146      도티&잠뜰: 브리티니 왕국의 비밀(Sandbox Friends 코믹 시리즈 2)
#  189  190  9788926366028             백종원이 추천하는 집밥 메뉴 55(백종원이 추천하는 집밥 메뉴 3)
#  190  191  9788992441858                                 말주변이 없어도 대화 잘하는 법
#  191  192  9788925561325                                       대한민국 부동산 투자
#  192  193  9791195857906                                     우리에겐 언어가 필요하다
#  193  194  9788967440886                    클로즈업 도쿄(2019)(개정판)(클로즈업 시리즈 2)
#  194  195  9791157528370                        나혼자 끝내는 독학 일본어 첫걸음(CD1장포함)
#  195  196  9788954637756                                          개인주의자 선언
#  196  197  9791158790721                                            사랑의 온도
#  197  198  9791185152431                                  내 문장이 그렇게 이상한가요?
#  198  199  9791158551957           해커스 OPIc 오픽 Advanced 공략(2주 만에 끝내는)(개정판)
#  199  200  9788927700821                                    최강 동물왕: 멸종동물 편
#
#                  저자명         출판사명       출간일       분야       정가
#  0               이기주          말글터  20160819    시/에세이  \13,800
#  1               조남주          민음사  20161014       소설  \13,000
#  2               윤홍균        심플라이프  20160901       인문  \14,000
#  3          히가시노 게이고         현대문학  20121219       소설  \14,800
#  4               김수현         마음의숲  20161128    시/에세이  \13,800
#  5               이기주         황소북스  20190318       인문  \14,500
#  6               김신회            놀  20170406    시/에세이  \16,000
#  7          무라카미 하루키         문학동네  20170712       소설  \16,300
#  8               김영하         문학동네  20130725       소설  \10,000
#  9               설민석          세계사  20160720    역사/문화  \22,000
#  10              유시민          돌베개  20170123       인문  \15,000
#  11              유시민         생각의길  20130313       인문  \15,000
#  12              김영하         문학동네  20170525       소설  \13,000
#  13         김용택 (엮음)           예담  20150604    시/에세이  \12,800
#  14          클라우스 슈밥        새로운현재  20160420    경제/경영  \15,000
#  15              채사장         한빛비즈  20170117       인문  \16,000
#  16          기시미 이치로        인플루엔셜  20141117       인문  \14,900
#  17           유발 하라리          김영사  20170519       인문  \22,000
#  18        베르나르 베르베르         열린책들  20170608       소설  \13,800
#  19           유발 하라리          김영사  20151124       인문  \22,000
#  20              고영성        로크미디어  20170106     자기계발  \19,800
#  21         앤절라 더크워스       비즈니스북스  20161028     자기계발  \16,000
#  22        David Cho     해커스어학연구소  20180810      외국어  \12,900
#  23           소노 아야코       책읽는고양이  20161020    시/에세이   \9,900
#  24              윤동주         더스토리  20160325    시/에세이   \7,700
#  25          신카이 마코토        대원씨아이  20170117       소설  \11,000
#  26               한강           창비  20071030       소설  \12,000
#  27         히가시노 게이고           재인  20170206       소설  \16,800
#  28   KBS <명견만리> 제작팀        인플루엔셜  20170605    경제/경영  \15,800
#  29              김민식       위즈덤하우스  20170111     자기계발  \14,000
#  ..              ...          ...       ...      ...      ...
#  170             정재승         어크로스  20110707       과학  \13,500
#  171             손원평           창비  20170331       소설  \12,000
#  172             김원철           알키  20161215    경제/경영  \16,000
#  173             김유라      한국경제신문사  20161025    경제/경영  \15,000
#  174           올댓스토리          아울북  20170202  어린이(초등)   \9,800
#  175          J.D.밴스         흐름출판  20170904    시/에세이  \14,800
#  176             허태균         중앙북스  20151207       인문  \16,000
#  177             유대영           겜툰  20170125  어린이(초등)   \9,800
#  178           마크 맨슨          갤리온  20171027     자기계발  \15,000
#  179          줄리언 반스         다산책방  20120326       소설  \12,800
#  180             유수진         세종서적  20170517    경제/경영  \15,000
#  181              트롤         아이세움  20170330  어린이(초등)  \12,000
#  182       David Cho     해커스어학연구소  20160404      외국어  \14,900
#  183             주진형       메디치미디어  20170405    경제/경영  \15,000
#  184             신영준        로크미디어  20160722      외국어  \12,000
#  185             이시원       시원스쿨닷컴  20121210      외국어  \15,000
#  186             김주연         지식너머  20150325       요리  \13,000
#  187           록산 게이         사이행성  20160314    정치/사회  \15,800
#  188             김현수         대원키즈  20161223  어린이(초등)   \9,500
#  189             백종원        서울문화사  20170421       요리   \9,900
#  190             김영돈           다연  20161010     자기계발  \13,000
#  191         김학렬(빠숑)      알에이치코리아  20170322    경제/경영  \16,500
#  192             이민경          봄알람  20160822    정치/사회  \12,000
#  193             유재우          에디터  20180716       여행  \17,000
#  194       넥서스콘텐츠개발팀  넥서스JAPANESE  20160627      외국어  \13,000
#  195             문유석         문학동네  20150923       인문  \13,500
#  196             하명희          북로드  20170918       소설  \13,000
#  197             김정선           유유  20160124       인문  \12,000
#  198       해커스 오픽연구소          해커스  20160712      외국어  \15,900
#  199      학연 컨텐츠 개발팀          다락원  20161220  어린이(초등)  \12,000
#
#  [200 rows x 8 columns],
#        순위           ISBN                                       도서명  \
#  0      1  9788925563350                       곰돌이 푸, 행복한 일은 매일 있어
#  1      2  9791162202913                                모든 순간이 너였다
#  2      3  9788957369364                       무례한 사람에게 웃으며 대처하는 법
#  3      4  9788937473135     82년생 김지영(오늘의 젊은 작가 13)(양장본 HardCover)
#  4      5  9791187119845                              나는 나로 살기로 했다
#  5      6  9791195522125                  언어의 온도(3주년 150만부 기념 에디션)
#  6      7  9791196394509                         죽고 싶지만 떡볶이는 먹고 싶어
#  7      8  9788998274795                               돌이킬 수 없는 약속
#  8      9  9788972756194                나미야 잡화점의 기적(양장본 HardCover)
#  9     10  9788971998557                                    역사의 역사
#  10    11  9788901219943                                 신경 끄기의 기술
#  11    12  9791185952987                      말 그릇(비울수록 사람을 더 채우는)
#  12    13  9788954637756                                  개인주의자 선언
#  13    14  9788965132288                                 어떻게 살 것인가
#  14    15  9788965236504                                3층 서기실의 암호
#  15    16  9791160560510                                    열두 발자국
#  16    17  9788997092772                                     말의 품격
#  17    18  9788925563367                       곰돌이 푸, 서두르지 않아도 괜찮아
#  18    19  9791161903538                                    연애의 행방
#  19    20  9788934972464                                      사피엔스
#  20    21  9791186757093                                    자존감 수업
#  21    22  9788901223032                            하마터면 열심히 살 뻔했다
#  22    23  9788965421832                  해커스 토익 기출 보카(TOEIC VOCA)
#  23    24  9788952775184                                   앨리스 죽이기
#  24    25  9788970656250                           만만하게 보이지 않는 대화법
#  25    26  9788932919126                     고양이. 1(양장본 HardCover)
#  26    27  9788968331503                  나, 있는 그대로 참 좋다(몽글몽글 에디션)
#  27    28  9788990982575                  가면산장 살인사건(양장본 HardCover)
#  28    29  9788994120966                        지적 대화를 위한 넓고 얕은 지식
#  29    30  9788932473802                                 어디서 살 것인가
#  ..   ...            ...                                       ...
#  170  171  9788992441575                                욱하는 성질 죽이기
#  171  172  9791187481423           앞으로 5년 미중전쟁 시나리오(양장본 HardCover)
#  172  173  9791133477296                         어벤져스 인피니티 워 캐릭터도감
#  173  174  9788968330889                                   나에게 고맙다
#  174  175  9791186560785                 수학이 필요한 순간(양장본 HardCover)
#  175  176  9788925563022                                내가 소홀했던 것들
#  176  177  9788935212224                              댄 애리얼리 부의 감각
#  177  178  9791161650401                             여행영어 100일의 기적
#  178  179  9791160401455                                   스님의 주례사
#  179  180  9791158510688                                    북유럽 신화
#  180  181  9788950966447                        프레임(양장본 HardCover)
#  181  182  9791159031076                        데미안(양장본 HardCover)
#  182  183  9788926366028     백종원이 추천하는 집밥 메뉴 55(백종원이 추천하는 집밥 메뉴 3)
#  183  184  9788901214801                        어쩌면 내가 가장 듣고 싶었던 말
#  184  185  9788950973063                               무엇이 되지 않더라도
#  185  186  9791162540145                                플랫폼 제국의 미래
#  186  187  9788932030395                 바다는 잘 있습니다(문학과지성 시인선 503)
#  187  188  9788996895107                      일빵빵 영어회화. 1(스토리가 있는)
#  188  189  9788992969536                             내가 만난 1%의 사람들
#  189  190  9788936476694                    나의 문화유산답사기: 산사 순례(반양장)
#  190  191  9791185419022              일빵빵 기초영어: 동사 조동사 편(입에 달고 사는)
#  191  192  9788970129792         꿈을 꾸었다고 말했다(제42회 이상문학상 작품집 2018년)
#  192  193  9788958628224                                시를 잊은 그대에게
#  193  194  9788925563770                  11문자 살인사건(양장본 HardCover)
#  194  195  9791189125264                             하루 5분 엄마의 말습관
#  195  196  9788983926845                                    오리진. 1
#  196  197  9788959139309        어쩌면 별들이 너의 슬픔을 가져갈지도 몰라(감성치유 라이팅북)
#  197  198  9788954643535                                   미스 함무라비
#  198  199  9788965422495  해커스 토익스피킹(토스) Level. 7 8(2주 만에 끝내는)(개정판)
#  199  200  9791186805992                   블루오션 시프트(양장본 HardCover)
#
#                저자명       출판사명       출간일       분야       정가
#  0      곰돌이 푸 (원작)    알에이치코리아  20180312    시/에세이  \12,000
#  1             하태완     위즈덤하우스  20180216    시/에세이  \13,800
#  2             정문정      가나출판사  20180108    시/에세이  \13,800
#  3             조남주        민음사  20161014       소설  \13,000
#  4             김수현       마음의숲  20161128    시/에세이  \13,800
#  5             이기주        말글터  20160819    시/에세이  \13,800
#  6             백세희          흔  20180620    시/에세이  \13,800
#  7         야쿠마루 가쿠       북플라자  20170202       소설  \15,000
#  8        히가시노 게이고       현대문학  20121219       소설  \14,800
#  9             유시민        돌베개  20180625    역사/문화  \16,000
#  10          마크 맨슨        갤리온  20171027     자기계발  \15,000
#  11            김윤나      카시오페아  20170922     자기계발  \15,000
#  12            문유석       문학동네  20150923       인문  \13,500
#  13            유시민       생각의길  20130313       인문  \15,000
#  14            태영호        기파랑  20180515    정치/사회  \20,000
#  15            정재승       어크로스  20180702       인문  \16,800
#  16            이기주       황소북스  20190318       인문  \14,500
#  17     곰돌이 푸 (원작)    알에이치코리아  20180508    시/에세이  \13,800
#  18       히가시노 게이고      소미미디어  20180131       소설  \13,800
#  19         유발 하라리        김영사  20151124       인문  \22,000
#  20            윤홍균      심플라이프  20160901       인문  \14,000
#  21             하완    웅진지식하우스  20180423    시/에세이  \15,000
#  22      David Cho   해커스어학연구소  20180810      외국어  \12,900
#  23       고바야시 야스미        검은숲  20151221       소설  \13,500
#  24       나이토 요시히토      홍익출판사  20180314     자기계발  \13,800
#  25      베르나르 베르베르       열린책들  20180612       소설  \12,800
#  26            조유미       허밍버드  20170922    시/에세이  \13,800
#  27       히가시노 게이고         재인  20140926       소설  \14,800
#  28            채사장       한빛비즈  20170117       인문  \16,000
#  29            유현준      을유문화사  20180530       인문  \16,000
#  ..            ...        ...       ...      ...      ...
#  170  로널드 T.포터-에프론         다연  20141010     자기계발  \15,000
#  171           최윤식      지식노마드  20180622    경제/경영  \25,000
#  172      대원키즈 편집부       대원키즈  20180420  어린이(초등)   \9,500
#  173           전승환       허밍버드  20160701    시/에세이  \13,800
#  174           김민형      인플루엔셜  20180803       과학  \15,800
#  175            흔글    알에이치코리아  20180117    시/에세이  \13,800
#  176        댄 애리얼리       청림출판  20180725    경제/경영  \18,000
#  177           문성현        넥서스  20170620      외국어  \12,000
#  178            법륜          휴  20180420       종교  \13,800
#  179         닐 게이먼      나무의철학  20170626    역사/문화  \14,800
#  180           최인철     21세기북스  20160831     자기계발  \16,000
#  181        헤르만 헤세       더스토리  20160627       소설   \9,800
#  182           백종원      서울문화사  20170421       요리   \9,900
#  183           정희재        갤리온  20170203    시/에세이  \14,000
#  184           김동영  아르테(arte)  20171218    시/에세이  \15,000
#  185       스콧 갤러웨이     비즈니스북스  20180430    경제/경영  \18,000
#  186           이병률     문학과지성사  20170920    시/에세이   \9,000
#  187           서장혁        토마토  20120601      외국어  \13,800
#  188      아담 J. 잭슨       씽크뱅크  20180110     자기계발  \15,000
#  189           유홍준         창비  20180830    역사/문화  \18,000
#  190           서장혁        토마토  20140102      외국어  \13,800
#  191           손홍규       문학사상  20180112       소설  \14,800
#  192           정재찬      휴머니스트  20150615    시/에세이  \15,000
#  193      히가시노 게이고    알에이치코리아  20180713       소설  \14,800
#  194           임영주      예담프렌드  20180806    가정/육아  \14,800
#  195         댄 브라운       문학수첩  20171123       소설  \13,000
#  196      김용택 (엮음)         예담  20150604    시/에세이  \12,800
#  197           문유석       문학동네  20161202       소설  \13,500
#  198     해커스 어학연구소   해커스어학연구소  20180122      외국어  \19,800
#  199           김위찬     비즈니스북스  20171230    경제/경영  \20,000
#
#  [200 rows x 8 columns]]

# %%
# 2000년도

# %%
B2000.count()
# Out:
# 순위      50
# ISBN    50
# 도서명     50
# 저자명     50
# 출판사명    50
# 출간일     50
# 분야      50
# 정가      50
# dtype: int64

# %%
B2000['분야'].value_counts()
# Out:
# 소설         16
# 시/에세이      12
# 자기계발        5
# 경제/경영       5
# 외국어         3
# 어린이(초등)     3
# 컴퓨터/IT      2
# 인문          2
# 정치/사회       1
# 역사/문화       1
# Name: 분야, dtype: int64

# %% [markdown]
# # 시각화

# %%
B2000['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2001['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2001_s = pd.Series(lst, index = ind)
B2001_df = pd.DataFrame(B2001_s)
B2001_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2002['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2003['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2004['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2005['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2006['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2007['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2008['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2009['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2010['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2011['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2012['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2013['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2014['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2015['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2016['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2017['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
B2018['분야'].value_counts()
ind = ["소설", "시/에세이", "자기계발", "경제/경영", "어린이(초등)", "외국어", "컴퓨터/IT", "인문", "역사/문화", "정치/사회"]
lst = [16, 12, 5, 5, 3, 3, 2, 2, 1, 1]
B2000_s = pd.Series(lst, index = ind)
B2000_df = pd.DataFrame(B2000_s)
B2000_df
# Out:
#           0
# 소설       16
# 시/에세이    12
# 자기계발      5
# 경제/경영     5
# 어린이(초등)   3
# 외국어       3
# 컴퓨터/IT    2
# 인문        2
# 역사/문화     1
# 정치/사회     1

# %%
labels = ind
sizes = lst

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()
