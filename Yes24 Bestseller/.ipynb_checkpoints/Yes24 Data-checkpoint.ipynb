# %%
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
for font in fm.fontManager.ttflist:
    if font.name in ['AppleGothic', 'Malgun Gothic']:
        plt.rcParams['font.family'] = font.name
        break
plt.rcParams['font.family']

# %matplotlib inline
mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams["axes.grid"] = True
plt.rcParams["figure.figsize"] = (14,4)

# %%
books = pd.read_csv('200801.csv', encoding = 'cp949')
books
# Out:
#     순위          ISBN     상품번호                         상품명      판매가  YES포인트  \
# 0    1  9.788984e+12  2742402              해리포터와 죽음의 성물 4   7,650원    420원
# 1    2  9.788984e+12  2742398              해리포터와 죽음의 성물 3   7,650원    420원
# 2    3  9.788952e+12  2599166              The Secret 시크릿  12,420원    690원
# 3    4  9.788984e+12  2721422              해리포터와 죽음의 성물 2   7,650원    420원
# 4    5  9.788984e+12  2721421              해리포터와 죽음의 성물 1   7,650원    420원
# 5    6  9.788972e+12  2752350                    즐거운 나의 집   8,820원    490원
# 6    7  9.788948e+12  2776013                마시멜로 두번째 이야기  10,800원    600원
# 7    8  9.788993e+12  2721480                        리버보이   8,100원    450원
# 8    9  9.788992e+12  2696491        대한민국 2030 재테크 독하게 하라   2,970원    160원
# 9   10  9.788932e+12  2710858                     친절한 복희씨  11,700원    650원
# 10  11  9.788993e+12  2296812                      무지개 원리  10,800원    600원
# 11  12  9.788976e+12  2774827                SERI 전망 2008  13,500원    750원
# 12  13  9.788973e+12  2746154                 천 개의 찬란한 태양  12,150원    670원
# 13  14  9.788991e+12  1953972     [2006년판] 해커스 토익 READING  17,860원    190원
# 14  15  9.788956e+12  2511675                        남한산성  11,700원    650원
# 15  16  9.788961e+12  2767770                          친구   9,000원    500원
# 16  17  9.788984e+12  2769949                    사랑하기 때문에   8,820원    490원
# 17  18  9.788996e+12  2710510                      잘 되는 나  10,800원    600원
# 18  19  9.788956e+12  2775888        스피드 리딩 SPEED READING  12,420원    690원
# 19  20  9.788901e+12  2767907                 신의진의 아이심리백과  18,000원  1,000원
# 20  21  9.788996e+12  2663580                   고슴도치의 우아함  11,700원    650원
# 21  22  9.788936e+12  2635373                        바리데기  11,700원    650원
# 22  23  9.788991e+12  1984885   [2006년판] 해커스 토익 LISTENING  17,860원    190원
# 23  24  9.788996e+12  2535862                      이기는 습관  10,800원    600원
# 24  25  9.788926e+12  2783642              몰입 Think hard!  10,800원    600원
# 25  26  9.788996e+12  2535237                      생각의 탄생  24,750원  1,370원
# 26  27  9.788991e+12  2299464                 사랑해 사랑해 사랑해   9,970원    100원
# 27  28  9.788961e+12  2711149                   나쁜 사마리아인들  12,600원    700원
# 28  29  9.788951e+12  2641353                    육일약국 갑시다  10,800원    600원
# 29  30  9.788957e+12  2716691                      1일 30분   9,900원    550원
# ..  ..           ...      ...                         ...      ...     ...
# 50  51  9.788972e+12  1791172           토마토 BASIC READING   8,910원    500원
# 51  52  9.788926e+12  2766739                   신의 물방울 13   4,500원    250원
# 52  53  9.788951e+12  2761321             인문의 숲에서 경영을 만나다  13,500원    750원
# 53  54  9.788948e+12  1809017                    마시멜로 이야기   9,000원    500원
# 54  55  9.788956e+12  2782142              그램그램 영문법 원정대 7   8,820원    490원
# 55  56  9.788977e+12  1821219                삐뽀삐뽀 119 이유식  10,710원    120원
# 56  57  9.788960e+12  1819114         토마토 BASIC LISTENING   8,910원    500원
# 57  58  9.788926e+12  2774742  39세 100억, 젊은 부자가 되는 7가지 방법  13,320원    740원
# 58  59  9.788935e+12  2753361                    황금나침반 세트  32,400원  1,800원
# 59  60  9.788938e+12  2746016               피라미드에서 살아남기 1   8,100원    450원
# 60  61  9.788981e+12   209455                    입이 큰 개구리   9,900원    550원
# 61  62  9.788901e+12   427973       사진과 그림으로 보는 한국사 편지 세트  45,000원  2,500원
# 62  63  9.788935e+12  2656016                      만들어진 신  22,500원  1,250원
# 63  64  9.788960e+12  2752631            네이티브는 쉬운 영어로 말한다   8,820원    490원
# 64  65  9.788953e+12  2796225       코믹 메이플스토리 오프라인 RPG 25   7,650원    420원
# 65  66  9.788930e+12  2657788              Why? 와이 별과 별자리   9,000원    500원
# 66  67  9.788956e+12  2533844                      지식 e 1  11,520원    640원
# 67  68  9.788901e+12  2750347                       침대와 책   9,900원    550원
# 68  69  9.788958e+12  2708625           노빈손 정조대왕의 암살을 막아라   8,550원    470원
# 69  70  9.788935e+12  2601301                   신도 버린 사람들   9,900원    550원
# 70  71  9.788938e+12  2720137                 우주에서 살아남기 2   8,100원    450원
# 71  72  9.788996e+12  2721632                    집으로 가는 길   8,820원    490원
# 72  73  9.788965e+12  2382061                       공부의 신  10,800원    600원
# 73  74  9.788901e+12  1431877              한권으로 읽는 조선왕조실록  16,200원    900원
# 74  75  9.788930e+12  2657785                 Why? 와이 미생물   9,000원    500원
# 75  76  9.788901e+12  2644513       금융회사가 당신에게 알려주지 않는 진실  10,800원    600원
# 76  77  9.788993e+12  2761175                       먹히는 말  13,500원    750원
# 77  78  9.788962e+12  2717357                    와인의 기쁨 1   9,000원    500원
# 78  79  9.788951e+12  2775999       야마다 사장, 샐러리맨의 천국을 만들다  10,800원    600원
# 79  80           NaN  2138160         버전업! 굿모닝 독학 일본어 첫걸음  12,150원    680원
#
#                             저자            출판사  \
# 0                  J.K. 롤링/최인자           문학수첩
# 1                  J.K. 롤링/최인자           문학수첩
# 2                     론다 번/김우열          살림Biz
# 3                  J.K. 롤링/최인자           문학수첩
# 4                  J.K. 롤링/최인자           문학수첩
# 5                          공지영            푸른숲
# 6          호아킴 데 포사다/엘런 싱어/공경희  한국경제신문사(한경비피)
# 7                    팀 보울러/정해영              놀
# 8                      김민수/이광배           미르북스
# 9                          박완서         문학과지성사
# 10                         차동엽          위즈앤비즈
# 11                  홍순영,전영재 등저        삼성경제연구소
# 12                할레드 호세이니/왕은철           현대문학
# 13                      데이비드 조       해커스어학연구소
# 14                          김훈            학고재
# 15                       스탠 톨러         위즈덤하우스
# 16                   기욤 뮈소/전미연           밝은세상
# 17                  조엘 오스틴/정성묵           긍정의힘
# 18                         신효상          롱테일북스
# 19                         신의진            갤리온
# 20                    뮈리엘 바르베리            아르테
# 76  대중을 열광케 한 명연설·명카피에서 찾아낸, 성공 커뮤니케이션을 위한 효과적인 언어...      3       국내도서-자기계발
# 77  '신의 물방울'의 저자 아기 다다시가 전하는 와인이야기. 와인 테이스팅법, 디캔팅 ...      3      국내도서-가정 살림
# 78  “인간(사원)은 말이 아니야. 당근과 채찍은 필요 없어. 당근만 주면 돼!” 일본 ...      3      국내도서-경제 경영
# 79  일본어를 전혀 모르는 완전초보자를 위한 독학용 일본어 학습서. 회화문을 통한 문법해...      3  국내도서-국어 외국어 사전
#
# [80 rows x 11 columns]

# %%
books['관리분류'].value_counts()
# Out:
# 국내도서-소설/시/희곡      17
# 국내도서-자기계발         12
# 국내도서-어린이          10
# 국내도서-경제 경영        10
# 국내도서-국어 외국어 사전     8
# 국내도서-가정 살림         6
# 국내도서-인문            5
# 국내도서-청소년           3
# 국내도서-종교            2
# 국내도서-유아            2
# 국내도서-사회 정치         2
# 국내도서-에세이           1
# 국내도서-만화/라이트노벨      1
# 국내도서-역사            1
# Name: 관리분류, dtype: int64

# %%
count = books.groupby('관리분류').count().drop(columns=['순위', '판매가', 'ISBN', '상품번호', 'YES포인트', '저자', '출판사', '설명', '출고예상일']).rename(columns={"상품명": "개수"})
count
# Out:
#                 개수
# 관리분류
# 국내도서-가정 살림       6
# 국내도서-경제 경영      10
# 국내도서-국어 외국어 사전   8
# 국내도서-만화/라이트노벨    1
# 국내도서-사회 정치       2
# 국내도서-소설/시/희곡    17
# 국내도서-어린이        10
# 국내도서-에세이         1
# 국내도서-역사          1
# 국내도서-유아          2
# 국내도서-인문          5
# 국내도서-자기계발       12
# 국내도서-종교          2
# 국내도서-청소년         3

# %%
books.insert(column = count['개수'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-14623c61b021> in <module>
# ----> 1 books.insert(column = count['개수'])
#
# TypeError: insert() missing 2 required positional arguments: 'loc' and 'value'

# %%
labels = books['관리분류']
sizes = count['개수']

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-1c36fe882ab4> in <module>
#       5
#       6 fig1, ax1 = plt.subplots()
# ----> 7 patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
#       8 for text in texts:
#       9     text.set_color('grey')
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels)
#    2981             explode = [0] * len(x)
#    2982         if len(x) != len(labels):
# -> 2983             raise ValueError("'label' must be of length 'x'")
#    2984         if len(x) != len(explode):
#    2985             raise ValueError("'explode' must be of length 'x'")
#
# ValueError: 'label' must be of length 'x'
