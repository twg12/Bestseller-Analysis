# %%
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
for font in fm.fontManager.ttflist:
    if font.name in ['AppleGothic', 'Malgun Gothic']:
        plt.rcParams['font.family'] = font.name
        break
plt.rcParams['font.family']

# %matplotlib inline
mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams["axes.grid"] = True
plt.rcParams["figure.figsize"] = (14,4)

# %%
books = pd.read_csv('201202.csv', encoding = 'cp949')
books
# Out:
#     순위          ISBN     상품번호                              상품명      판매가  \
# 0    1  9.788964e+12  5750451                        해를 품은 달 1  11,700원
# 1    2  9.788964e+12  5750452                        해를 품은 달 2  11,700원
# 2    3  9.791196e+12  5982086           어떻게 원하는 것을 얻는가 밀리언 특별판  14,400원
# 3    4  9.788966e+12  4447549                        아프니까 청춘이다  12,600원
# 4    5  9.788972e+12  5715338                           닥치고 정치  12,150원
# 5    6  9.788951e+12  6166704                         마법천자문 20   8,820원
# 6    7  9.788901e+12  5696349                   시골의사 박경철의 자기혁명  14,400원
# 7    8  9.788937e+12  5788279                           스티브 잡스  22,500원
# 8    9  9.788959e+12  6091408                     오늘 내가 살아갈 이유  11,610원
# 9   10  9.788933e+12  5875356                             웃음 1  12,420원
# 10  11  9.788984e+12  6020303                           천사의 부름  12,150원
# 11  12  9.788977e+12  6092236                           잊혀진 질문  14,400원
# 12  13  9.788994e+12  5912070                          달려라 정봉주  12,150원
# 13  14  9.788933e+12  5875360                             웃음 2  12,420원
# 14  15  9.788966e+12  5968733                             절대강자  13,050원
# 15  16  9.788955e+12  4346834                        리딩으로 리드하라  13,500원
# 16  17  9.788964e+12  5635366                     독서 천재가 된 홍대리  11,700원
# 17  18  9.788991e+12  3103556                해커스 토익 Reading 리딩  17,860원
# 18  19  9.788966e+12  6190758                  멈추면, 비로소 보이는 것들  12,600원
# 19  20  9.788957e+12  6130874                    어쨌거나 남자는 필요하다  11,250원
# 20  21  9.788901e+12  4473092                    여자를 증오한 남자들 1  11,700원
# 21  22  9.788994e+12  5911925                            고구려 4  11,520원
# 22  23  9.788984e+12  5764559                            엄마 수업  10,800원
# 23  24  9.788984e+12  3906597                             빅 픽처  10,800원
# 24  25  9.788955e+12  5976292                          모르는 여인들  10,800원
# 25  26  9.788991e+12  3103577             해커스 토익 Listening 리스닝  17,860원
# 26  27  9.788901e+12  4473094                    여자를 증오한 남자들 2  11,700원
# 27  28  9.788965e+12  5273111             해커스 토익 보카 Vocabulary  12,250원
# 28  29  9.788960e+12  6024999                 셜록 홈즈 실크 하우스의 비밀  10,800원
# 29  30  9.788964e+12  6132681                   운명을 바꾸는 10년 통장  11,700원
# ..  ..           ...      ...                              ...      ...
# 50  51  9.788951e+12  6103916                   부자들은 왜 장지갑을 쓸까  11,700원
# 51  52  9.788994e+12  5889602                     무라카미 하루키 잡문집  13,320원
# 52  53  9.788971e+12  1477636                               논어  13,500원
# 53  54  9.788955e+12  5815659                        십자군 이야기 2  13,110원
# 10  기욤 뮈소의 아홉 번째 소설인『천사의 부름』은 작가의 변신을 널리 알리는 작품인 동...      1
# 11  평생 종교를 갖지 않았던 삼성 이병철 회장이 1987년 타계하기 전 가깝게 지내던 ...      3
# 12  나꼼수 4인방 중 유일한 정치인인 정봉주 전 의원이 국민의 열화와 같은 성원에 탄력...      1
# 13  유머의 생산과 유통이라는 이색 소재로 그려 낸 미스터리 소설 『개미』의 작가 베르나...      1
# 14  “지금 살아 있다는 사실만으로도 그대는 절대강자다” -이외수 세월이 흘러도 변함없는...      1
# 15  개인, 가족, 기업, 국가의 운명을 변화시키는 인문고전 독서의 가공할 위력! 아인슈...      3
# 16  나를 살리는 생존 독서를 시작하라 스무 권이 넘는 책을 펴내고 국내에서만 총 200...      3
# 17  문법 · 독해 · 어휘에서 실전까지 대비한 토익 기본서 최신 경향을 반영하여 문법,...      3
# 18  사람들에게 치여 상처받고 눈물 날 때, 그토록 원했던 일이 이루어지지 않았을 때, ...      3
# 19  남인숙은 2004년 출간한 『여자의 모든 인생은 20대에 결정된다』를 통해 80만 ...      3
# 20  전 세계적으로 '밀레니엄 신드롬'을 일으킨 시리즈 《밀레니엄》 3부작 정의를 구현하...      3
# 21  『무궁화꽃이 피었습니다』의 작가 김진명이 선보이는 필생의 역작. 속도감 있는 전개와...      1
# 22  자녀 문제로 괴로워하는 부모에게 법륜 스님이 주는 다정한 조언이자 지혜로 가득 찬 ...      1
# 23  진정 '나'를 위한 삶을 살고 싶었던 한 남자 이야기 영미작가이지만 프랑스를 비롯한...      1
# 24  전 세계 31개국 독자들과 함께 읽는 작가, 신경숙 8년 만에 출간하는 7편의 마스...      2
# 25  유형별 접근을 통해 실전 공략한 토익 기본서 최신 경향을 반영하여 Part1에서 P...      3
# 26  전 세계적으로 '밀레니엄 신드롬'을 일으킨 시리즈 《밀레니엄》 3부작 정의를 구현하...      3
# 27  주제별 연상학습 기능을 수행하는 구성으로 30일만에 토익 기출 단어를 섭렵할 수 있...      3
# 28  작가 앤터니 호로비츠가 아서 코난 도일 재단의 공식 『셜록 홈즈』 작가로 임명된 후...      1
# 29  대부분의 사람들은 30~40대에 번 돈으로 평생을 살아갈 준비를 한다. 하지만 오늘...      2
# ..                                                ...    ...
# 50  돈을 부르는 지갑의 비밀은? 주머니에 땡전 한 푼 없던 노숙자에서 수많은 기업 경영...      3
# 51  당신이 사랑하는 작가, 무라카미 하루키의 모든 것 30년 하루키 문학의 집대성 "설...      1
# 52  『논어(論語)』는 공자와 그 제자들이 세상사는 이치나 교육ㆍ문화ㆍ정치 등에 관해 논...      3
# 53  “신이 그것을 바라신다”, 이 한 마디의 힘은 엄청났다. 교황 우르바누스 2세의 이...      1
# 54  토익 최신 출제 경향과 난이도를 반영한 실전 문제집 토익 문제를 완전히 분석한 결과...      3
# 55  폐쇄적 분지 마을에서 일어나는 일련의 사건과 그 속에 숨은 인간 내면의 추악한 본성...      1
# 김성오                         1
# 차동엽                         1
# 파울로 코엘료                     1
# 론다 번/김우열                    1
# 신의진                         1
# 이원복                         1
# 신효상                         1
# 파피루스/이금돌/김광태                1
# 공지영                         1
# 우석훈/박권일                     1
# 조엘 오스틴/정성묵                  1
# 스탠 톨러                       1
# 남동욱/이우일                     1
# 황석영                         1
# 키스 포크너                      1
# 한상복                         1
# 할레드 호세이니/왕은철                1
# Name: 저자, Length: 70, dtype: int64

# %%
books['관리분류'].value_counts()
# Out:
# 국내도서-소설/시/희곡      17
# 국내도서-자기계발         12
# 국내도서-어린이          10
# 국내도서-경제 경영        10
# 국내도서-국어 외국어 사전     8
# 국내도서-가정 살림         6
# 국내도서-인문            5
# 국내도서-청소년           3
# 국내도서-종교            2
# 국내도서-유아            2
# 국내도서-사회 정치         2
# 국내도서-에세이           1
# 국내도서-만화/라이트노벨      1
# 국내도서-역사            1
# Name: 관리분류, dtype: int64

# %%
count = books.groupby('관리분류').count().drop(columns=['순위', '판매가', 'ISBN', '상품번호', 'YES포인트', '저자', '출판사', '설명', '출고예상일']).rename(columns={"상품명": "개수"})
count
# Out:
#                 개수
# 관리분류
# 국내도서-가정 살림       6
# 국내도서-경제 경영      10
# 국내도서-국어 외국어 사전   8
# 국내도서-만화/라이트노벨    1
# 국내도서-사회 정치       2
# 국내도서-소설/시/희곡    17
# 국내도서-어린이        10
# 국내도서-에세이         1
# 국내도서-역사          1
# 국내도서-유아          2
# 국내도서-인문          5
# 국내도서-자기계발       12
# 국내도서-종교          2
# 국내도서-청소년         3

# %%
books.insert(column = count['개수'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-14623c61b021> in <module>
# ----> 1 books.insert(column = count['개수'])
#
# TypeError: insert() missing 2 required positional arguments: 'loc' and 'value'

# %%
labels = books['관리분류']
sizes = count['개수']

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-1c36fe882ab4> in <module>
#       5
#       6 fig1, ax1 = plt.subplots()
# ----> 7 patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
#       8 for text in texts:
#       9     text.set_color('grey')
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels)
#    2981             explode = [0] * len(x)
#    2982         if len(x) != len(labels):
# -> 2983             raise ValueError("'label' must be of length 'x'")
#    2984         if len(x) != len(explode):
#    2985             raise ValueError("'explode' must be of length 'x'")
#
# ValueError: 'label' must be of length 'x'
