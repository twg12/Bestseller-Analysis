# %%
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
for font in fm.fontManager.ttflist:
    if font.name in ['AppleGothic', 'Malgun Gothic']:
        plt.rcParams['font.family'] = font.name
        break
plt.rcParams['font.family']

# %matplotlib inline
mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams["axes.grid"] = True
plt.rcParams["figure.figsize"] = (14,4)

# %%
books = pd.read_csv('200801.csv', encoding = 'cp949')
books
# Out:
#     순위          ISBN     상품번호                    상품명      판매가 YES포인트  \
# 0    1  9.788984e+12  2742402         해리포터와 죽음의 성물 4   7,650원   420원
# 1    2  9.788984e+12  2742398         해리포터와 죽음의 성물 3   7,650원   420원
# 2    3  9.788952e+12  2599166         The Secret 시크릿  12,420원   690원
# 3    4  9.788984e+12  2721422         해리포터와 죽음의 성물 2   7,650원   420원
# 4    5  9.788984e+12  2721421         해리포터와 죽음의 성물 1   7,650원   420원
# ..  ..           ...      ...                    ...      ...    ...
# 75  76  9.788901e+12  2644513  금융회사가 당신에게 알려주지 않는 진실  10,800원   600원
# 76  77  9.788993e+12  2761175                  먹히는 말  13,500원   750원
# 77  78  9.788962e+12  2717357               와인의 기쁨 1   9,000원   500원
# 78  79  9.788951e+12  2775999  야마다 사장, 샐러리맨의 천국을 만들다  10,800원   600원
# 79  80           NaN  2138160    버전업! 굿모닝 독학 일본어 첫걸음  12,150원   680원
#
#                저자          출판사  \
# 0     J.K. 롤링/최인자         문학수첩
# 1     J.K. 롤링/최인자         문학수첩
# 2        론다 번/김우열        살림Biz
# ...

# %%
books['저자'].value_counts().head()
# Out:
# J.K. 롤링/최인자      4
# 데이비드 조           3
# 아기 타다시/오키모토 슈    2
# 하정훈              2
# 송도수/서정은          2
# Name: 저자, dtype: int64

# %%
books['관리분류'].value_counts()
# Out:
# 국내도서-소설/시/희곡      17
# 국내도서-자기계발         12
# 국내도서-어린이          10
# 국내도서-경제 경영        10
# 국내도서-국어 외국어 사전     8
# 국내도서-가정 살림         6
# 국내도서-인문            5
# 국내도서-청소년           3
# 국내도서-종교            2
# 국내도서-유아            2
# 국내도서-사회 정치         2
# 국내도서-만화/라이트노벨      1
# 국내도서-역사            1
# 국내도서-에세이           1
# Name: 관리분류, dtype: int64

# %%
count = books.groupby('관리분류').count().drop(columns=['순위', '판매가', 'ISBN', '상품번호', 'YES포인트', '저자', '출판사', '설명', '출고예상일']).rename(columns={"상품명": "개수"})
count
# Out:
#                 개수
# 관리분류
# 국내도서-가정 살림       6
# 국내도서-경제 경영      10
# 국내도서-국어 외국어 사전   8
# 국내도서-만화/라이트노벨    1
# 국내도서-사회 정치       2
# 국내도서-소설/시/희곡    17
# 국내도서-어린이        10
# 국내도서-에세이         1
# 국내도서-역사          1
# 국내도서-유아          2
# 국내도서-인문          5
# 국내도서-자기계발       12
# 국내도서-종교          2
# 국내도서-청소년         3

# %%
labels = list(books['관리분류'].unique())
sizes = books['관리분류'].value_counts()

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
fig1, ax1 = plt.subplots()
patches, texts, autotexts = ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
for text in texts:
    text.set_color('grey')
for autotext in autotexts:
    autotext.set_color('grey')

ax1.axis('equal')  
plt.tight_layout()
plt.title('20xx')
plt.show()

# %% [markdown]
# ## 질문할 것: 어떻게 merge()를 해서 '기타'로 만들 것인가?

# %%
books = pd.read_csv('200801.csv', encoding = 'cp949')
books.head(2)
# Out:
#    순위          ISBN     상품번호             상품명     판매가 YES포인트           저자  \
# 0   1  9.788984e+12  2742402  해리포터와 죽음의 성물 4  7,650원   420원  J.K. 롤링/최인자
# 1   2  9.788984e+12  2742398  해리포터와 죽음의 성물 3  7,650원   420원  J.K. 롤링/최인자
#
#     출판사                                                 설명  출고예상일  \
# 0  문학수첩  1997년부터 2007년까지, 무려 10년이라는 긴 시간 끝에 해리포터 시리즈 드디...      4
# 1  문학수첩  1997년부터 2007년까지, 무려 10년이라는 긴 시간 끝에 해리포터 시리즈 드디...      4
#
#            관리분류
# 0  국내도서-소설/시/희곡
# 1  국내도서-소설/시/희곡

# %%
for count(i) in books:
    if count(i)

# %%
books.count()
# Out:
# 순위        80
# ISBN      79
# 상품번호      80
# 상품명       80
# 판매가       80
# YES포인트    80
# 저자        80
# 출판사       80
# 설명        80
# 출고예상일     80
# 관리분류      80
# dtype: int64

# %%
books[books['ISBN'] == int]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-3a2ebc1aa4fa> in <module>
# ----> 1 books[books['ISBN'].type() == int]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'type'
