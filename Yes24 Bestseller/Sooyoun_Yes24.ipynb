# %%
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
for font in fm.fontManager.ttflist:
    if font.name in ['AppleGothic', 'Malgun Gothic']:
        plt.rcParams['font.family'] = font.name
        break
plt.rcParams['font.family']

# %matplotlib inline
mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams["axes.grid"] = True
plt.rcParams["figure.figsize"] = (14,4)

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# ## 예스24 2008년~2019년 월별 베스트셀러 데이터 가져오기

# %%
#2008년
Yes24_200801 = pd.read_csv('200801.csv', encoding = 'cp949')
Yes24_200802 = pd.read_csv('200802.csv', encoding = 'cp949')
Yes24_200803 = pd.read_csv('200803.csv', encoding = 'cp949')
Yes24_200804 = pd.read_csv('200804.csv', encoding = 'cp949')
Yes24_200805 = pd.read_csv('200805.csv', encoding = 'cp949')
Yes24_200806 = pd.read_csv('200806.csv', encoding = 'cp949')
Yes24_200807 = pd.read_csv('200807.csv', encoding = 'cp949')
Yes24_200808 = pd.read_csv('200808.csv', encoding = 'cp949')
Yes24_200809 = pd.read_csv('200809.csv', encoding = 'cp949')
Yes24_200810 = pd.read_csv('200810.csv', encoding = 'cp949')
Yes24_200811 = pd.read_csv('200811.csv', encoding = 'cp949')
Yes24_200812 = pd.read_csv('200812.csv', encoding = 'cp949')

#2009년
Yes24_200901 = pd.read_csv('200901.csv', encoding = 'cp949')
Yes24_200902 = pd.read_csv('200902.csv', encoding = 'cp949')
Yes24_200903 = pd.read_csv('200903.csv', encoding = 'cp949')
Yes24_200904 = pd.read_csv('200904.csv', encoding = 'cp949')
Yes24_200905 = pd.read_csv('200905.csv', encoding = 'cp949')
Yes24_200906 = pd.read_csv('200906.csv', encoding = 'cp949')
Yes24_200907 = pd.read_csv('200907.csv', encoding = 'cp949')
Yes24_200908 = pd.read_csv('200908.csv', encoding = 'cp949')
Yes24_200909 = pd.read_csv('200909.csv', encoding = 'cp949')
Yes24_200910 = pd.read_csv('200910.csv', encoding = 'cp949')
Yes24_200911 = pd.read_csv('200911.csv', encoding = 'cp949')
Yes24_200912 = pd.read_csv('200912.csv', encoding = 'cp949')

#2010년
Yes24_201001 = pd.read_csv('201001.csv', encoding = 'cp949')
Yes24_201002 = pd.read_csv('201002.csv', encoding = 'cp949')
Yes24_201003 = pd.read_csv('201003.csv', encoding = 'cp949')
Yes24_201004 = pd.read_csv('201004.csv', encoding = 'cp949')
Yes24_201005 = pd.read_csv('201005.csv', encoding = 'cp949')
Yes24_201006 = pd.read_csv('201006.csv', encoding = 'cp949')
Yes24_201007 = pd.read_csv('201007.csv', encoding = 'cp949')
Yes24_201008 = pd.read_csv('201008.csv', encoding = 'cp949')
Yes24_201009 = pd.read_csv('201009.csv', encoding = 'cp949')
Yes24_201010 = pd.read_csv('201010.csv', encoding = 'cp949')
Yes24_201011 = pd.read_csv('201011.csv', encoding = 'cp949')
Yes24_201012 = pd.read_csv('201012.csv', encoding = 'cp949')

#2011년
Yes24_201101 = pd.read_csv('201101.csv', encoding = 'cp949')
Yes24_201102 = pd.read_csv('201102.csv', encoding = 'cp949')
Yes24_201103 = pd.read_csv('201103.csv', encoding = 'cp949')
Yes24_201104 = pd.read_csv('201104.csv', encoding = 'cp949')
Yes24_201105 = pd.read_csv('201105.csv', encoding = 'cp949')
Yes24_201106 = pd.read_csv('201106.csv', encoding = 'cp949')
Yes24_201107 = pd.read_csv('201107.csv', encoding = 'cp949')
Yes24_201108 = pd.read_csv('201108.csv', encoding = 'cp949')
Yes24_201109 = pd.read_csv('201109.csv', encoding = 'cp949')
Yes24_201110 = pd.read_csv('201110.csv', encoding = 'cp949')
Yes24_201111 = pd.read_csv('201111.csv', encoding = 'cp949')
Yes24_201112 = pd.read_csv('201112.csv', encoding = 'cp949')

#2012년
Yes24_201201 = pd.read_csv('201201.csv', encoding = 'cp949')
Yes24_201202 = pd.read_csv('201202.csv', encoding = 'cp949')
Yes24_201203 = pd.read_csv('201203.csv', encoding = 'cp949')
Yes24_201204 = pd.read_csv('201204.csv', encoding = 'cp949')
Yes24_201205 = pd.read_csv('201205.csv', encoding = 'cp949')
Yes24_201206 = pd.read_csv('201206.csv', encoding = 'cp949')
Yes24_201207 = pd.read_csv('201207.csv', encoding = 'cp949')
Yes24_201208 = pd.read_csv('201208.csv', encoding = 'cp949')
Yes24_201209 = pd.read_csv('201209.csv', encoding = 'cp949')
Yes24_201210 = pd.read_csv('201210.csv', encoding = 'cp949')
Yes24_201211 = pd.read_csv('201211.csv', encoding = 'cp949')
Yes24_201212 = pd.read_csv('201212.csv', encoding = 'cp949')

#2013년
Yes24_201301 = pd.read_csv('201301.csv', encoding = 'cp949')
Yes24_201302 = pd.read_csv('201302.csv', encoding = 'cp949')
Yes24_201303 = pd.read_csv('201303.csv', encoding = 'cp949')
Yes24_201304 = pd.read_csv('201304.csv', encoding = 'cp949')
Yes24_201305 = pd.read_csv('201305.csv', encoding = 'cp949')
Yes24_201306 = pd.read_csv('201306.csv', encoding = 'cp949')
Yes24_201307 = pd.read_csv('201307.csv', encoding = 'cp949')
Yes24_201308 = pd.read_csv('201308.csv', encoding = 'cp949')
Yes24_201309 = pd.read_csv('201309.csv', encoding = 'cp949')
Yes24_201310 = pd.read_csv('201310.csv', encoding = 'cp949')
Yes24_201311 = pd.read_csv('201311.csv', encoding = 'cp949')
Yes24_201312 = pd.read_csv('201312.csv', encoding = 'cp949')

#2014년
Yes24_201401 = pd.read_csv('201401.csv', encoding = 'cp949')
Yes24_201402 = pd.read_csv('201402.csv', encoding = 'cp949')
Yes24_201403 = pd.read_csv('201403.csv', encoding = 'cp949')
Yes24_201404 = pd.read_csv('201404.csv', encoding = 'cp949')
Yes24_201405 = pd.read_csv('201405.csv', encoding = 'cp949')
Yes24_201406 = pd.read_csv('201406.csv', encoding = 'cp949')
Yes24_201407 = pd.read_csv('201407.csv', encoding = 'cp949')
Yes24_201408 = pd.read_csv('201408.csv', encoding = 'cp949')
Yes24_201409 = pd.read_csv('201409.csv', encoding = 'cp949')
Yes24_201410 = pd.read_csv('201410.csv', encoding = 'cp949')
Yes24_201411 = pd.read_csv('201411.csv', encoding = 'cp949')
Yes24_201412 = pd.read_csv('201412.csv', encoding = 'cp949')

#2015년
Yes24_201501 = pd.read_csv('201501.csv', encoding = 'cp949')
Yes24_201502 = pd.read_csv('201502.csv', encoding = 'cp949')
Yes24_201503 = pd.read_csv('201503.csv', encoding = 'cp949')
Yes24_201504 = pd.read_csv('201504.csv', encoding = 'cp949')
Yes24_201505 = pd.read_csv('201505.csv', encoding = 'cp949')
Yes24_201506 = pd.read_csv('201506.csv', encoding = 'cp949')
Yes24_201507 = pd.read_csv('201507.csv', encoding = 'cp949')
Yes24_201508 = pd.read_csv('201508.csv', encoding = 'cp949')
Yes24_201509 = pd.read_csv('201509.csv', encoding = 'cp949')
Yes24_201510 = pd.read_csv('201510.csv', encoding = 'cp949')
Yes24_201511 = pd.read_csv('201511.csv', encoding = 'cp949')
Yes24_201512 = pd.read_csv('201512.csv', encoding = 'cp949')

#2016년
Yes24_201601 = pd.read_csv('201601.csv', encoding = 'cp949')
Yes24_201602 = pd.read_csv('201602.csv', encoding = 'cp949')
Yes24_201603 = pd.read_csv('201603.csv', encoding = 'cp949')
Yes24_201604 = pd.read_csv('201604.csv', encoding = 'cp949')
Yes24_201605 = pd.read_csv('201605.csv', encoding = 'cp949')
Yes24_201606 = pd.read_csv('201606.csv', encoding = 'cp949')
Yes24_201607 = pd.read_csv('201607.csv', encoding = 'cp949')
Yes24_201608 = pd.read_csv('201608.csv', encoding = 'cp949')
Yes24_201609 = pd.read_csv('201609.csv', encoding = 'cp949')
Yes24_201610 = pd.read_csv('201610.csv', encoding = 'cp949')
Yes24_201611 = pd.read_csv('201611.csv', encoding = 'cp949')
Yes24_201612 = pd.read_csv('201612.csv', encoding = 'cp949')

#2017년
Yes24_201701 = pd.read_csv('201701.csv', encoding = 'cp949')
Yes24_201702 = pd.read_csv('201702.csv', encoding = 'cp949')
Yes24_201703 = pd.read_csv('201703.csv', encoding = 'cp949')
Yes24_201704 = pd.read_csv('201704.csv', encoding = 'cp949')
Yes24_201705 = pd.read_csv('201705.csv', encoding = 'cp949')
Yes24_201706 = pd.read_csv('201706.csv', encoding = 'cp949')
Yes24_201707 = pd.read_csv('201707.csv', encoding = 'cp949')
Yes24_201708 = pd.read_csv('201708.csv', encoding = 'cp949')
Yes24_201709 = pd.read_csv('201709.csv', encoding = 'cp949')
Yes24_201710 = pd.read_csv('201710.csv', encoding = 'cp949')
Yes24_201711 = pd.read_csv('201711.csv', encoding = 'cp949')
Yes24_201712 = pd.read_csv('201712.csv', encoding = 'cp949')

#2018년
Yes24_201801 = pd.read_csv('201801.csv', encoding = 'cp949')
Yes24_201802 = pd.read_csv('201802.csv', encoding = 'cp949')
Yes24_201803 = pd.read_csv('201803.csv', encoding = 'cp949')
Yes24_201804 = pd.read_csv('201804.csv', encoding = 'cp949')
Yes24_201805 = pd.read_csv('201805.csv', encoding = 'cp949')
Yes24_201806 = pd.read_csv('201806.csv', encoding = 'cp949')
Yes24_201807 = pd.read_csv('201807.csv', encoding = 'cp949')
Yes24_201808 = pd.read_csv('201808.csv', encoding = 'cp949')
Yes24_201809 = pd.read_csv('201809.csv', encoding = 'cp949')
Yes24_201810 = pd.read_csv('201810.csv', encoding = 'cp949')
Yes24_201811 = pd.read_csv('201811.csv', encoding = 'cp949')
Yes24_201812 = pd.read_csv('201812.csv', encoding = 'cp949')

#2019년
Yes24_201901 = pd.read_csv('201901.csv', encoding = 'cp949')
Yes24_201902 = pd.read_csv('201902.csv', encoding = 'cp949')
Yes24_201903 = pd.read_csv('201903.csv', encoding = 'cp949')
Yes24_201904 = pd.read_csv('201904.csv', encoding = 'cp949')
Yes24_201905 = pd.read_csv('201905.csv', encoding = 'cp949')
Yes24_201906 = pd.read_csv('201906.csv', encoding = 'cp949')
Yes24_201907 = pd.read_csv('201907.csv', encoding = 'cp949')
Yes24_201908 = pd.read_csv('201908.csv', encoding = 'cp949')
Yes24_201909 = pd.read_csv('201909.csv', encoding = 'cp949')
Yes24_201910 = pd.read_csv('201910.csv', encoding = 'cp949')
Yes24_201911 = pd.read_csv('201911.csv', encoding = 'cp949')

# %%
Yes24_200801.head(1)
# Out:
#    순위          ISBN     상품번호             상품명     판매가 YES포인트           저자  \
# 0   1  9.788984e+12  2742402  해리포터와 죽음의 성물 4  7,650원   420원  J.K. 롤링/최인자
#
#     출판사                                                 설명  출고예상일  \
# 0  문학수첩  1997년부터 2007년까지, 무려 10년이라는 긴 시간 끝에 해리포터 시리즈 드디...      4
#
#            관리분류
# 0  국내도서-소설/시/희곡

# %% [markdown]
# ## 데이터프레임 정제
# 1. Month, Year 칼럼 추가하고 연 별로 묶기

# %%
#2008년 
Yes24_200801['Month'] = 1
Yes24_200802['Month'] = 2
Yes24_200803['Month'] = 3
Yes24_200804['Month'] = 4
Yes24_200805['Month'] = 5
Yes24_200806['Month'] = 6
Yes24_200807['Month'] = 7
Yes24_200808['Month'] = 8
Yes24_200809['Month'] = 9
Yes24_200810['Month'] = 10
Yes24_200811['Month'] = 11
Yes24_200812['Month'] = 12

List_2008 = [Yes24_200801, Yes24_200802, Yes24_200803, Yes24_200804, Yes24_200805, Yes24_200806, Yes24_200807, Yes24_200808, Yes24_200809, Yes24_200810, Yes24_200811, Yes24_200812]

for bs_list in List_2008:
    bs_list['Year'] = '2008'

Yes24_2008 = pd.concat([Yes24_200801, Yes24_200802, Yes24_200803, Yes24_200804, Yes24_200805, Yes24_200806, Yes24_200807, Yes24_200808, Yes24_200809, Yes24_200810, Yes24_200811, Yes24_200812], ignore_index=True)

# %%
#2009년
Yes24_200901['Month'] = '1'
Yes24_200902['Month'] = '2'
Yes24_200903['Month'] = '3'
Yes24_200904['Month'] = '4'
Yes24_200905['Month'] = '5'
Yes24_200906['Month'] = '6'
Yes24_200907['Month'] = '7'
Yes24_200908['Month'] = '8'
Yes24_200909['Month'] = '9'
Yes24_200910['Month'] = '10'
Yes24_200911['Month'] = '11'
Yes24_200912['Month'] = '12'

List_2009 = [Yes24_200901, Yes24_200902, Yes24_200903, Yes24_200904, Yes24_200905, Yes24_200906, Yes24_200907, Yes24_200908, Yes24_200909, Yes24_200910, Yes24_200911, Yes24_200912]

for bs_list in List_2009:
        bs_list['Year'] = '2009'

Yes24_2009 = pd.concat([Yes24_200901, Yes24_200902, Yes24_200903, Yes24_200904, Yes24_200905, Yes24_200906, Yes24_200907, Yes24_200908, Yes24_200909, Yes24_200910, Yes24_200911, Yes24_200912], ignore_index=True)

#2010년
Yes24_201001['Month'] = 1
Yes24_201002['Month'] = 2
Yes24_201003['Month'] = 3
Yes24_201004['Month'] = 4
Yes24_201005['Month'] = 5
Yes24_201006['Month'] = 6
Yes24_201007['Month'] = 7
Yes24_201008['Month'] = 8
Yes24_201009['Month'] = 9
Yes24_201010['Month'] = 10
Yes24_201011['Month'] = 11
Yes24_201012['Month'] = 12

List_2010 = [Yes24_201001, Yes24_201002, Yes24_201003, Yes24_201004, Yes24_201005, Yes24_201006, Yes24_201007, Yes24_201008, Yes24_201009, Yes24_201010, Yes24_201011, Yes24_201012]

for bs_list in List_2010:
        bs_list['Year'] = '2010'
        
Yes24_2010 = pd.concat([Yes24_201001, Yes24_201002, Yes24_201003, Yes24_201004, Yes24_201005, Yes24_201006, Yes24_201007, Yes24_201008, Yes24_201009, Yes24_201010, Yes24_201011, Yes24_201012], ignore_index=True)

#2011년
Yes24_201101['Month'] = 1
Yes24_201102['Month'] = 2
Yes24_201103['Month'] = 3
Yes24_201104['Month'] = 4
Yes24_201105['Month'] = 5
Yes24_201106['Month'] = 6
Yes24_201107['Month'] = 7
Yes24_201108['Month'] = 8
Yes24_201109['Month'] = 9
Yes24_201110['Month'] = 10
Yes24_201111['Month'] = 11
Yes24_201112['Month'] = 12

List_2011 = [Yes24_201101, Yes24_201102, Yes24_201103, Yes24_201104, Yes24_201105, Yes24_201106, Yes24_201107, Yes24_201108, Yes24_201109, Yes24_201110, Yes24_201111, Yes24_201112]

for bs_list in List_2011:
        bs_list['Year'] = '2011'

Yes24_2011 = pd.concat([Yes24_201101, Yes24_201102, Yes24_201103, Yes24_201104, Yes24_201105, Yes24_201106, Yes24_201107, Yes24_201108, Yes24_201109, Yes24_201110, Yes24_201111, Yes24_201112], ignore_index=True)

#2012년
Yes24_201201['Month'] = 1
Yes24_201202['Month'] = 2
Yes24_201203['Month'] = 3
Yes24_201204['Month'] = 4
Yes24_201205['Month'] = 5
Yes24_201206['Month'] = 6
Yes24_201207['Month'] = 7
Yes24_201208['Month'] = 8
Yes24_201209['Month'] = 9
Yes24_201210['Month'] = 10
Yes24_201211['Month'] = 11
Yes24_201212['Month'] = 12

List_2012 = [Yes24_201201, Yes24_201202, Yes24_201203, Yes24_201204, Yes24_201205, Yes24_201206, Yes24_201207, Yes24_201208, Yes24_201209, Yes24_201210, Yes24_201211, Yes24_201212]

for bs_list in List_2012:
        bs_list['Year'] = '2012'

Yes24_2012 = pd.concat([Yes24_201201, Yes24_201202, Yes24_201203, Yes24_201204, Yes24_201205, Yes24_201206, Yes24_201207, Yes24_201208, Yes24_201209, Yes24_201210, Yes24_201211, Yes24_201212], ignore_index=True)

#2013년
Yes24_201301['Month'] = 1
Yes24_201302['Month'] = 2
Yes24_201303['Month'] = 3
Yes24_201304['Month'] = 4
Yes24_201305['Month'] = 5
Yes24_201306['Month'] = 6
Yes24_201307['Month'] = 7
Yes24_201308['Month'] = 8
Yes24_201309['Month'] = 9
Yes24_201310['Month'] = 10
Yes24_201311['Month'] = 11
Yes24_201312['Month'] = 12

List_2013 = [Yes24_201301, Yes24_201302, Yes24_201303, Yes24_201304, Yes24_201305, Yes24_201306, Yes24_201307, Yes24_201308, Yes24_201309, Yes24_201310, Yes24_201311, Yes24_201312]

for bs_list in List_2013:
        bs_list['Year'] = '2013'

Yes24_2013 = pd.concat([Yes24_201301, Yes24_201302, Yes24_201303, Yes24_201304, Yes24_201305, Yes24_201306, Yes24_201307, Yes24_201308, Yes24_201309, Yes24_201310, Yes24_201311, Yes24_201312], ignore_index=True)

#2014년
Yes24_201401['Month'] = 1
Yes24_201402['Month'] = 2
Yes24_201403['Month'] = 3
Yes24_201404['Month'] = 4
Yes24_201405['Month'] = 5
Yes24_201406['Month'] = 6
Yes24_201407['Month'] = 7
Yes24_201408['Month'] = 8
Yes24_201409['Month'] = 9
Yes24_201410['Month'] = 10
Yes24_201411['Month'] = 11
Yes24_201412['Month'] = 12

List_2014 = [Yes24_201401, Yes24_201402, Yes24_201403, Yes24_201404, Yes24_201405, Yes24_201406, Yes24_201407, Yes24_201408, Yes24_201409, Yes24_201410, Yes24_201411, Yes24_201412]

for bs_list in List_2014:
        bs_list['Year'] = '2014'

Yes24_2014 = pd.concat([Yes24_201401, Yes24_201402, Yes24_201403, Yes24_201404, Yes24_201405, Yes24_201406, Yes24_201407, Yes24_201408, Yes24_201409, Yes24_201410, Yes24_201411, Yes24_201412], ignore_index=True)

#2015년
Yes24_201501['Month'] = 1
Yes24_201502['Month'] = 2
Yes24_201503['Month'] = 3
Yes24_201504['Month'] = 4
Yes24_201505['Month'] = 5
Yes24_201506['Month'] = 6
Yes24_201507['Month'] = 7
Yes24_201508['Month'] = 8
Yes24_201509['Month'] = 9
Yes24_201510['Month'] = 10
Yes24_201511['Month'] = 11
Yes24_201512['Month'] = 12

List_2015 = [Yes24_201501, Yes24_201502, Yes24_201503, Yes24_201504, Yes24_201505, Yes24_201506, Yes24_201507, Yes24_201508, Yes24_201509, Yes24_201510, Yes24_201511, Yes24_201512]

for bs_list in List_2015:
        bs_list['Year'] = '2015'

Yes24_2015 = pd.concat([Yes24_201501, Yes24_201502, Yes24_201503, Yes24_201504, Yes24_201505, Yes24_201506, Yes24_201507, Yes24_201508, Yes24_201509, Yes24_201510, Yes24_201511, Yes24_201512], ignore_index=True)

#2016년
Yes24_201601['Month'] = 1
Yes24_201602['Month'] = 2
Yes24_201603['Month'] = 3
Yes24_201604['Month'] = 4
Yes24_201605['Month'] = 5
Yes24_201606['Month'] = 6
Yes24_201607['Month'] = 7
Yes24_201608['Month'] = 8
Yes24_201609['Month'] = 9
Yes24_201610['Month'] = 10
Yes24_201611['Month'] = 11
Yes24_201612['Month'] = 12

List_2016 = [Yes24_201601, Yes24_201602, Yes24_201603, Yes24_201604, Yes24_201605, Yes24_201606, Yes24_201607, Yes24_201608, Yes24_201609, Yes24_201610, Yes24_201611, Yes24_201612]

for bs_list in List_2016:
        bs_list['Year'] = '2016'

Yes24_2016 = pd.concat([Yes24_201601, Yes24_201602, Yes24_201603, Yes24_201604, Yes24_201605, Yes24_201606, Yes24_201607, Yes24_201608, Yes24_201609, Yes24_201610, Yes24_201611, Yes24_201612], ignore_index=True)

#2017년
Yes24_201701['Month'] = 1
Yes24_201702['Month'] = 2
Yes24_201703['Month'] = 3
Yes24_201704['Month'] = 4
Yes24_201705['Month'] = 5
Yes24_201706['Month'] = 6
Yes24_201707['Month'] = 7
Yes24_201708['Month'] = 8
Yes24_201709['Month'] = 9
Yes24_201710['Month'] = 10
Yes24_201711['Month'] = 11
Yes24_201712['Month'] = 12

List_2017 = [Yes24_201701, Yes24_201702, Yes24_201703, Yes24_201704, Yes24_201705, Yes24_201706, Yes24_201707, Yes24_201708, Yes24_201709, Yes24_201710, Yes24_201711, Yes24_201712]

for bs_list in List_2017:
        bs_list['Year'] = '2017'

Yes24_2017 = pd.concat([Yes24_201701, Yes24_201702, Yes24_201703, Yes24_201704, Yes24_201705, Yes24_201706, Yes24_201707, Yes24_201708, Yes24_201709, Yes24_201710, Yes24_201711, Yes24_201712], ignore_index=True)

#2018년
Yes24_201801['Month'] = 1
Yes24_201802['Month'] = 2
Yes24_201803['Month'] = 3
Yes24_201804['Month'] = 4
Yes24_201805['Month'] = 5
Yes24_201806['Month'] = 6
Yes24_201807['Month'] = 7
Yes24_201808['Month'] = 8
Yes24_201809['Month'] = 9
Yes24_201810['Month'] = 10
Yes24_201811['Month'] = 11
Yes24_201812['Month'] = 12

List_2018 = [Yes24_201801, Yes24_201802, Yes24_201803, Yes24_201804, Yes24_201805, Yes24_201806, Yes24_201807, Yes24_201808, Yes24_201809, Yes24_201810, Yes24_201811, Yes24_201812]

for bs_list in List_2018:
        bs_list['Year'] = '2018'

Yes24_2018 = pd.concat([Yes24_201801, Yes24_201802, Yes24_201803, Yes24_201804, Yes24_201805, Yes24_201806, Yes24_201807, Yes24_201808, Yes24_201809, Yes24_201810, Yes24_201811, Yes24_201812], ignore_index=True)

#2019년
Yes24_201901['Month'] = 1
Yes24_201902['Month'] = 2
Yes24_201903['Month'] = 3
Yes24_201904['Month'] = 4
Yes24_201905['Month'] = 5
Yes24_201906['Month'] = 6
Yes24_201907['Month'] = 7
Yes24_201908['Month'] = 8
Yes24_201909['Month'] = 9
Yes24_201910['Month'] = 10
Yes24_201911['Month'] = 11

List_2019 = [Yes24_201901, Yes24_201902, Yes24_201903, Yes24_201904, Yes24_201905, Yes24_201906, Yes24_201907, Yes24_201908, Yes24_201909, Yes24_201910, Yes24_201911]

for bs_list in List_2019:
        bs_list['Year'] = '2019'
        
Yes24_2019 = pd.concat([Yes24_201901, Yes24_201902, Yes24_201903, Yes24_201904, Yes24_201905, Yes24_201906, Yes24_201907, Yes24_201908, Yes24_201909, Yes24_201910, Yes24_201911], ignore_index=True)

# %% [markdown]
# 2. 필요 없는 칼럼 삭제(drop) 후 .csv 파일로 저장

# %%
Total = pd.concat([Yes24_2008, Yes24_2009, Yes24_2010, Yes24_2011, Yes24_2012, Yes24_2013, Yes24_2014, Yes24_2015, Yes24_2016,Yes24_2017,Yes24_2018,Yes24_2019], sort = False)
Yes24 = Total.drop(columns=['출고예상일', 'YES포인트', '상품번호'])
Yes24.to_csv('Yes24.csv', encoding='utf-8', index=False)

# %%
Yes24_2008.to_csv('Yes24_2008.csv', encoding='utf-8', index=False)
Yes24_2009.to_csv('Yes24_2009.csv', encoding='utf-8', index=False)
Yes24_2010.to_csv('Yes24_2010.csv', encoding='utf-8', index=False)
Yes24_2011.to_csv('Yes24_2011.csv', encoding='utf-8', index=False)
Yes24_2012.to_csv('Yes24_2012.csv', encoding='utf-8', index=False)
Yes24_2013.to_csv('Yes24_2013.csv', encoding='utf-8', index=False)
Yes24_2014.to_csv('Yes24_2014.csv', encoding='utf-8', index=False)
Yes24_2015.to_csv('Yes24_2015.csv', encoding='utf-8', index=False)
Yes24_2016.to_csv('Yes24_2016.csv', encoding='utf-8', index=False)
Yes24_2017.to_csv('Yes24_2017.csv', encoding='utf-8', index=False)
Yes24_2018.to_csv('Yes24_2018.csv', encoding='utf-8', index=False)
Yes24_2019.to_csv('Yes24_2019.csv', encoding='utf-8', index=False)

# %% [markdown]
# 2008년부터 2019년 11월까지 매 월 상위 80개 베스트셀러 데이터프레임 완성
#
# ## 데이터 Explore

# %%
Yes24.head(3)
# Out:
#    순위          ISBN             상품명      판매가           저자    출판사  \
# 0   1  9.788984e+12  해리포터와 죽음의 성물 4   7,650원  J.K. 롤링/최인자   문학수첩
# 1   2  9.788984e+12  해리포터와 죽음의 성물 3   7,650원  J.K. 롤링/최인자   문학수첩
# 2   3  9.788952e+12  The Secret 시크릿  12,420원     론다 번/김우열  살림Biz
#
#                                                   설명          관리분류 Month  Year
# 0  1997년부터 2007년까지, 무려 10년이라는 긴 시간 끝에 해리포터 시리즈 드디...  국내도서-소설/시/희곡     1  2008
# 1  1997년부터 2007년까지, 무려 10년이라는 긴 시간 끝에 해리포터 시리즈 드디...  국내도서-소설/시/희곡     1  2008
# 2  인생을 성공으로 이끄는 ‘위대한 비밀’의 단편들은 오래 전부터 구전과 문학과 종교와...     국내도서-자기계발     1  2008

# %%
# 어떤 분야 책들이 많이 읽혔을까? 2008~2019.11
genre = pd.DataFrame(Yes24['관리분류'].value_counts())
genre.head(3)
# Out:
#               관리분류
# 국내도서-소설/시/희곡  2088
# 국내도서-자기계발     1363
# 국내도서-에세이      1096

# %% [markdown]
# -- 의외의 분야에서 베스트셀러에 든 책들

# %%
Yes24[Yes24['관리분류']=='국내도서-종교-(미분류)-(미분류)']
# Out:
#      순위          ISBN      상품명     판매가  저자 출판사  \
# 359  40  9.788946e+12  버리고 떠나기  7,650원  법정  샘터
#
#                                                     설명                 관리분류  \
# 359  1992년 홀연히 불일암을 떠나 강원도 오두막에 기거하면서부터 쓴 글들을 모았다. ...  국내도서-종교-(미분류)-(미분류)
#
#     Month  Year
# 359     5  2010

# %%
Yes24[Yes24['관리분류']=='국내도서-전집']
# Out:
#      순위  ISBN                           상품명       판매가       저자     출판사   설명  \
# 314  75   NaN  탐구가 즐거워지는 명랑사회 세이펜버젼 (본책64권)  225,720원  이수출판출판부  이수(전집)  NaN
#
#         관리분류 Month  Year
# 314  국내도서-전집     4  2019

# %%
Yes24[Yes24['관리분류']=='국내도서-대학교재']
# Out:
#      순위          ISBN         상품명      판매가                   저자       출판사  \
# 798  79  9.788972e+12  New Path 1  15,200원  김남희,문도식,박수정,쥬디 인 공저  한양대학교출판부
#
#                                                     설명       관리분류 Month  Year
# 798  New Path 1은 국제 공용어로서의 영어의 중요성이 날로 증대하고 있는 국제화 ...  국내도서-대학교재    10  2010

# %% [markdown]
# 2008년~ 2018년 분야 별 베스트셀러에 오른 책 count

# %%
#2008년
genre2008 = pd.DataFrame(Yes24_2008['관리분류'].value_counts())
genre2008
# Out:
#                         관리분류
# 국내도서-소설/시/희곡             184
# 국내도서-자기계발                149
# 국내도서-경제 경영               121
# 국내도서-어린이                 106
# 국내도서-국어 외국어 사전            87
# 국내도서-가정 살림                62
# 국내도서-유아                   61
# 국내도서-에세이                  49
# 국내도서-인문                   31
# 국내도서-청소년                  21
# 국내도서-건강 취미                18
# 국내도서-만화/라이트노벨-라이트노벨       17
# 국내도서-종교                   14
# 국내도서-만화/라이트노벨             12
# 국내도서-사회 정치                 8
# 국내도서-예술                    6
# 국내도서-역사                    6
# 국내도서-여행                    3
# 국내도서-경제 경영-(미분류)-(미분류)     2
# 국내도서-사회 정치-(미분류)-(미분류)     1
# 국내도서-자연과학                  1
# 국내도서-가정 살림-(미분류)-(미분류)     1

# %%
genre2008.to_excel("genre2008.xlsx")  # flourish에서 파이 그래프 그리기 위해 엑셀 파일로 추출

# %%
#2009년
genre2009 = pd.DataFrame(Yes24_2009['관리분류'].value_counts())
genre2009.to_excel("genre2009.xlsx")

#2010년
genre2010 = pd.DataFrame(Yes24_2010['관리분류'].value_counts())
genre2010.to_excel("genre2010.xlsx")

#2011년
genre2011 = pd.DataFrame(Yes24_2011['관리분류'].value_counts())
genre2011.to_excel("genre2011.xlsx")

#2012년
genre2012 = pd.DataFrame(Yes24_2012['관리분류'].value_counts())
genre2012.to_excel("genre2012.xlsx")

#2013년
genre2013 = pd.DataFrame(Yes24_2013['관리분류'].value_counts())
genre2013.to_excel("genre2013.xlsx")

#2014년
genre2014 = pd.DataFrame(Yes24_2014['관리분류'].value_counts())
genre2014.to_excel("genre2014.xlsx")

#2015년
genre2015 = pd.DataFrame(Yes24_2015['관리분류'].value_counts())
genre2015.to_excel("genre2015.xlsx")

#2016년
genre2016 = pd.DataFrame(Yes24_2016['관리분류'].value_counts())
genre2016.to_excel("genre2016.xlsx")

#2017년
genre2017 = pd.DataFrame(Yes24_2017['관리분류'].value_counts())
genre2017.to_excel("genre2010.xlsx")

#2018년
genre2018 = pd.DataFrame(Yes24_2018['관리분류'].value_counts())
genre2018.to_excel("genre2018.xlsx")

# %%
genre2018_ = pd.read_excel('genre2018.xlsx', index_col=0)
genre2018_
# Out:
#                      관리분류
# 국내도서-에세이              131
# 국내도서-소설/시/희곡          120
# 국내도서-국어 외국어 사전        111
# 국내도서-어린이               99
# 국내도서-자기계발              96
# 국내도서-수험서 자격증           89
# 국내도서-인문                81
# 국내도서-경제 경영             72
# 국내도서-가정 살림             37
# 국내도서-만화/라이트노벨          30
# 국내도서-역사                21
# 국내도서-사회 정치             15
# 국내도서-유아                14
# 국내도서-자연과학              12
# 국내도서-건강 취미             10
# 국내도서-예술                 7
# 국내도서-만화/라이트노벨-라이트노벨     4
# 국내도서-유아-토이북             3
# 국내도서-청소년                2
# CD/LP-가요-댄스-댄스          2
# 국내도서-종교                 2
# 국내도서-IT 모바일             2

# %% [markdown]
# Q1. 베스트셀러 1위에 가장 많이 오른 책은?

# %%
Top1_Yes24 = Yes24[Yes24['순위'].isin([1])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2166c1d5365f> in <module>
# ----> 1 Top1_Yes24 = Yes24[Yes24['순위'].isin([1])]
#
# NameError: name 'Yes24' is not defined

# %%
Yes24['상품명'].value_counts().head(5)
# Out:
# 삐뽀삐뽀 119 소아과            91
# 임신 출산 육아 대백과            73
# 나미야 잡화점의 기적             70
# 사랑해 사랑해 사랑해             68
# 해커스 토익 보카 Vocabulary    67
# Name: 상품명, dtype: int64

# %% [markdown]
# A1. <미움받을 용기>가 1위, <멈추면, 비로소 보이는 것들>이 2위

# %% [markdown]
# Q2. 베스트셀러 top80에 가장 많이 등장한 책은?

# %%
popular_book = pd.value_counts(Yes24['상품명'].values, ascending=False)
popular_book.head(5)
# Out:
# 삐뽀삐뽀 119 소아과            91
# 임신 출산 육아 대백과            73
# 나미야 잡화점의 기적             70
# 사랑해 사랑해 사랑해             68
# 해커스 토익 보카 Vocabulary    67
# dtype: int64

# %% [markdown]
# A2. <삐뽀삐뽀 119 소아과>와 <임신 출산 육아 대백과>가 1, 2위.
# 육아 관련 책이 꾸준히 팔리고 있다는 것을 알 수 있다.

# %% [markdown]
# Q3. top80위에 가장 자주 등장한 인기 저자는?

# %%
popular_author = pd.value_counts(Yes24['저자'].values, ascending=False)
popular_author.head(10)
# Out:
# 데이비드 조         337
# 편집부 저          118
# 하정훈            117
# 설민석            116
# ETS            115
# David Cho 저    110
# 이지성            107
# 채사장             98
# 전한길             97
# 유시민             95
# dtype: int64

# %% [markdown]
# A3. 데이비드 조(David Cho)가 압도적 1위. 그가 쓴 책은?  해커스 토익 책!

# %%
Yes24[Yes24['저자'].isin(['데이비드 조', 'David Cho'])]
# Out:
#      순위          ISBN                        상품명      판매가         저자  \
# 13   14  9.788991e+12    [2006년판] 해커스 토익 READING  17,860원     데이비드 조
# 22   23  9.788991e+12  [2006년판] 해커스 토익 LISTENING  17,860원     데이비드 조
# 47   48  9.788991e+12       해커스 토익 보카 Vocabulary  12,250원     데이비드 조
# 89   10  9.788991e+12    [2006년판] 해커스 토익 READING  17,860원     데이비드 조
# 92   13  9.788991e+12  [2006년판] 해커스 토익 LISTENING  17,860원     데이비드 조
# 104  25  9.788991e+12       해커스 토익 보카 Vocabulary  12,250원     데이비드 조
# 176  17  9.788991e+12    [2006년판] 해커스 토익 READING  17,860원     데이비드 조
# 187  28  9.788991e+12  [2006년판] 해커스 토익 LISTENING  17,860원     데이비드 조
# 204  45  9.788991e+12       해커스 토익 보카 Vocabulary  12,250원     데이비드 조
# 244   5  9.788991e+12    [2006년판] 해커스 토익 READING  17,860원     데이비드 조
# 257  18  9.788991e+12  [2006년판] 해커스 토익 LISTENING  17,860원     데이비드 조
# 260  21  9.788991e+12       해커스 토익 보카 Vocabulary  12,250원     데이비드 조
# 311  72  9.788991e+12      해커스 토익 스타트 Reading 리딩  14,150원     데이비드 조
# ...

# %%
Yes24['관리분류'].unique()
# Out:
# array(['국내도서-소설/시/희곡', '국내도서-자기계발', '국내도서-경제 경영', '국내도서-국어 외국어 사전',
#        '국내도서-종교', '국내도서-가정 살림', '국내도서-인문', '국내도서-유아', '국내도서-어린이',
#        '국내도서-사회 정치', '국내도서-에세이', '국내도서-청소년', '국내도서-만화/라이트노벨', '국내도서-역사',
#        '국내도서-건강 취미', '국내도서-여행', '국내도서-만화/라이트노벨-라이트노벨', '국내도서-자연과학',
#        '국내도서-예술', '국내도서-가정 살림-(미분류)-(미분류)', '국내도서-경제 경영-(미분류)-(미분류)',
#        '국내도서-사회 정치-(미분류)-(미분류)', '국내도서-국어 외국어 사전-(미분류)-(미분류)',
#        '국내도서-종교-(미분류)-(미분류)', '국내도서-대학교재', '국내도서-예술-대중문화(통합)',
#        '국내도서-수험서 자격증', '전자책 단말기-CREMA', '국내도서-유아-토이북', '국내도서-IT 모바일',
#        'CD/LP-가요-댄스-댄스', '국내도서-전집'], dtype=object)

# %% [markdown]
# Q4. 베스트셀러 작가의 성비는?

# %%
Yes24.to_excel("Yes24.xlsx", sheet_name='Yes24_total')  # doctest: +SKIP
Yes24_monthly = Yes24.copy()
with pd.ExcelWriter('Yes24.xlsx') as writer:  # doctest: +SKIP
        Yes24_2008.to_excel(writer, sheet_name='2008')
        Yes24_2009.to_excel(writer, sheet_name='2009')
        Yes24_2010.to_excel(writer, sheet_name='2010')
        Yes24_2011.to_excel(writer, sheet_name='2011')
        Yes24_2012.to_excel(writer, sheet_name='2012')
        Yes24_2013.to_excel(writer, sheet_name='2013')
        Yes24_2014.to_excel(writer, sheet_name='2014')
        Yes24_2015.to_excel(writer, sheet_name='2015')
        Yes24_2016.to_excel(writer, sheet_name='2016')
        Yes24_2017.to_excel(writer, sheet_name='2017')
        Yes24_2018.to_excel(writer, sheet_name='2018')
        Yes24_2019.to_excel(writer, sheet_name='2019')

# %% [markdown]
# ## 베스트셀러 시즈널리티 찾아보기

# %%
# 2008년 한 해 '소설/시/희곡' 시즈널리티 찾아보기
Literature = Yes24[Yes24["관리분류"] =='국내도서-소설/시/희곡'].groupby(['Month']).size().reset_index()
Literature_2008 = Yes24_2008[Yes24_2008["관리분류"] == '국내도서-소설/시/희곡'].groupby('Month').size().reset_index()
Literature_2008 = Literature_2008.rename(columns={0:"소설/시/희곡"})
Literature_2008.head()
# Out:
#    Month  소설/시/희곡
# 0      1       17
# 1      2       18
# 2      3       14
# 3      4       14
# 4      5       14

# %% [markdown]
# 2008년~ 2019년(11월까지)도 '소설/시/희곡' 그래프 그리기

# %%
## 2008년

x = Literature_2008['Month']
y = Literature_2008["소설/시/희곡"]

plt.plot(x, y, color = 'r')
plt.title('2008_소설/시/희곡')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2009년

Literature_2009 = Yes24_2009[Yes24_2009["관리분류"] == '국내도서-소설/시/희곡'].groupby('Month').size().reset_index()
Literature_2009 = Literature_2009.rename(columns={0:"소설/시/희곡"})
Literature_2009.head()

x = Literature_2009['Month']
y = Literature_2009["소설/시/희곡"]

plt.plot(x, y, color = 'r')
plt.title('2009_소설/시/희곡')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2010년

Literature_2010 = Yes24_2010[Yes24_2010["관리분류"] == '국내도서-소설/시/희곡'].groupby('Month').size().reset_index()
Literature_2010 = Literature_2010.rename(columns={0:"소설/시/희곡"})
Literature_2010.head()

x = Literature_2010['Month']
y = Literature_2010["소설/시/희곡"]

plt.plot(x, y, color = 'r')
plt.title('2010_소설/시/희곡')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2011년 

Literature_2011 = Yes24_2011[Yes24_2011["관리분류"] == '국내도서-소설/시/희곡'].groupby('Month').size().reset_index()
Literature_2011 = Literature_2011.rename(columns={0:"소설/시/희곡"})
Literature_2011.head()

x = Literature_2011['Month']
y = Literature_2011["소설/시/희곡"]

plt.plot(x, y, color = 'r')
plt.title('2011_소설/시/희곡')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2012년 

Literature_2012 = Yes24_2012[Yes24_2012["관리분류"] == '국내도서-소설/시/희곡'].groupby('Month').size().reset_index()
Literature_2012 = Literature_2012.rename(columns={0:"소설/시/희곡"})
Literature_2012.head()

x = Literature_2012['Month']
y = Literature_2012["소설/시/희곡"]

plt.plot(x, y, color = 'r')
plt.title('2012_소설/시/희곡')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2013년 

Literature_2013 = Yes24_2013[Yes24_2013["관리분류"] == '국내도서-소설/시/희곡'].groupby('Month').size().reset_index()
Literature_2013 = Literature_2013.rename(columns={0:"소설/시/희곡"})
Literature_2009.head()

x = Literature_2013['Month']
y = Literature_2013["소설/시/희곡"]

plt.plot(x, y, color = 'r')
plt.title('2013_소설/시/희곡')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2014년 

Literature_2014 = Yes24_2014[Yes24_2014["관리분류"] == '국내도서-소설/시/희곡'].groupby('Month').size().reset_index()
Literature_2014 = Literature_2014.rename(columns={0:"소설/시/희곡"})
Literature_2014.head()

x = Literature_2014['Month']
y = Literature_2014["소설/시/희곡"]

plt.plot(x, y, color = 'r')
plt.title('2014_소설/시/희곡')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2015년 

Literature_2015 = Yes24_2015[Yes24_2015["관리분류"] == '국내도서-소설/시/희곡'].groupby('Month').size().reset_index()
Literature_2015 = Literature_2015.rename(columns={0:"소설/시/희곡"})
Literature_2015.head()

x = Literature_2015['Month']
y = Literature_2015["소설/시/희곡"]

plt.plot(x, y, color = 'r')
plt.title('2015_소설/시/희곡')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2016년 

Literature_2016 = Yes24_2016[Yes24_2016["관리분류"] == '국내도서-소설/시/희곡'].groupby('Month').size().reset_index()
Literature_2016 = Literature_2016.rename(columns={0:"소설/시/희곡"})
Literature_2016.head()

x = Literature_2016['Month']
y = Literature_2016["소설/시/희곡"]

plt.plot(x, y, color = 'r')
plt.title('2016_소설/시/희곡')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2017년 

Literature_2017 = Yes24_2017[Yes24_2017["관리분류"] == '국내도서-소설/시/희곡'].groupby('Month').size().reset_index()
Literature_2017 = Literature_2017.rename(columns={0:"소설/시/희곡"})
Literature_2017.head()

x = Literature_2017['Month']
y = Literature_2017["소설/시/희곡"]

plt.plot(x, y, color = 'r')
plt.title('2017_소설/시/희곡')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2018년 

Literature_2018 = Yes24_2018[Yes24_2018["관리분류"] == '국내도서-소설/시/희곡'].groupby('Month').size().reset_index()
Literature_2018 = Literature_2018.rename(columns={0:"소설/시/희곡"})
Literature_2018.head()

x = Literature_2018['Month']
y = Literature_2018["소설/시/희곡"]

plt.plot(x, y, color = 'r')
plt.title('2018_소설/시/희곡')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2019년 (11월까지)

Literature_2019 = Yes24_2019[Yes24_2019["관리분류"] == '국내도서-소설/시/희곡'].groupby('Month').size().reset_index()
Literature_2019 = Literature_2019.rename(columns={0:"소설/시/희곡"})
Literature_2019.head()

x = Literature_2019['Month']
y = Literature_2019["소설/시/희곡"]

plt.plot(x, y, color = 'r')
plt.title('2019_소설/시/희곡')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

# %% [markdown]
# 2008년~ 2019년(11월까지)도 '자기계발' 그래프 그리기
# : 매 월 베스트셀러 80위 안에 자기계발 카테고리에 속한 책이 몇 권이나 되나

# %%
## 2008년
Self_Dev = Yes24[Yes24["관리분류"] =='국내도서-자기계발'].groupby(['Month']).size().reset_index()
Self_Dev_2008 = Yes24_2008[Yes24_2008["관리분류"] == '국내도서-자기계발'].groupby('Month').size().reset_index()
Self_Dev_2008 = Self_Dev_2008.rename(columns={0:"자기계발"})

x = Self_Dev_2008['Month']
y = Self_Dev_2008["자기계발"]

plt.plot(x, y, color = 'r')
plt.title('2008_자기계발')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2009년 
Self_Dev_2009 = Yes24_2008[Yes24_2009["관리분류"] == '국내도서-자기계발'].groupby('Month').size().reset_index()
Self_Dev_2009 = Self_Dev_2009.rename(columns={0:"자기계발"})

x = Self_Dev_2009['Month']
y = Self_Dev_2009["자기계발"]

plt.plot(x, y, color = 'r')
plt.title('2009_자기계발')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2010년

Self_Dev_2010 = Yes24_2010[Yes24_2010["관리분류"] == '국내도서-자기계발'].groupby('Month').size().reset_index()
Self_Dev_2010 = Self_Dev_2010.rename(columns={0:"자기계발"})

x = Self_Dev_2010['Month']
y = Self_Dev_2010["자기계발"]

plt.plot(x, y, color = 'r')
plt.title('2010_자기계발')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2011년

Self_Dev_2011 = Yes24_2011[Yes24_2011["관리분류"] == '국내도서-자기계발'].groupby('Month').size().reset_index()
Self_Dev_2011 = Self_Dev_2011.rename(columns={0:"자기계발"})

x = Self_Dev_2011['Month']
y = Self_Dev_2011["자기계발"]

plt.plot(x, y, color = 'r')
plt.title('2011_자기계발')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2012년 

Self_Dev_2012 = Yes24_2012[Yes24_2012["관리분류"] == '국내도서-자기계발'].groupby('Month').size().reset_index()
Self_Dev_2012 = Self_Dev_2012.rename(columns={0:"자기계발"})

x = Self_Dev_2012['Month']
y = Self_Dev_2012["자기계발"]

plt.plot(x, y, color = 'r')
plt.title('2012_자기계발')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2013년 


Self_Dev_2013 = Yes24_2013[Yes24_2013["관리분류"] == '국내도서-자기계발'].groupby('Month').size().reset_index()
Self_Dev_2013 = Self_Dev_2013.rename(columns={0:"자기계발"})

x = Self_Dev_2013['Month']
y = Self_Dev_2013["자기계발"]

plt.plot(x, y, color = 'r')
plt.title('2013_자기계발')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2014년

Self_Dev_2014 = Yes24_2014[Yes24_2014["관리분류"] == '국내도서-자기계발'].groupby('Month').size().reset_index()
Self_Dev_2014 = Self_Dev_2014.rename(columns={0:"자기계발"})

x = Self_Dev_2014['Month']
y = Self_Dev_2014["자기계발"]

plt.plot(x, y, color = 'r')
plt.title('2014_자기계발')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2015년 

Self_Dev_2015 = Yes24_2015[Yes24_2015["관리분류"] == '국내도서-자기계발'].groupby('Month').size().reset_index()
Self_Dev_2015 = Self_Dev_2015.rename(columns={0:"자기계발"})

x = Self_Dev_2015['Month']
y = Self_Dev_2015["자기계발"]

plt.plot(x, y, color = 'r')
plt.title('2015_자기계발')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2016년 

Self_Dev_2016 = Yes24_2016[Yes24_2016["관리분류"] == '국내도서-자기계발'].groupby('Month').size().reset_index()
Self_Dev_2016 = Self_Dev_2016.rename(columns={0:"자기계발"})

x = Self_Dev_2016['Month']
y = Self_Dev_2016["자기계발"]

plt.plot(x, y, color = 'r')
plt.title('2016_자기계발')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2017년

Self_Dev_2017 = Yes24_2017[Yes24_2017["관리분류"] == '국내도서-자기계발'].groupby('Month').size().reset_index()
Self_Dev_2017 = Self_Dev_2017.rename(columns={0:"자기계발"})

x = Self_Dev_2017['Month']
y = Self_Dev_2017["자기계발"]

plt.plot(x, y, color = 'r')
plt.title('2017_자기계발')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2018년 

Self_Dev_2018 = Yes24_2018[Yes24_2018["관리분류"] == '국내도서-자기계발'].groupby('Month').size().reset_index()
Self_Dev_2018 = Self_Dev_2018.rename(columns={0:"자기계발"})

x = Self_Dev_2018['Month']
y = Self_Dev_2018["자기계발"]

plt.plot(x, y, color = 'r')
plt.title('2018_자기계발')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

## 2019년

Self_Dev_2019 = Yes24_2019[Yes24_2019["관리분류"] == '국내도서-자기계발'].groupby('Month').size().reset_index()
Self_Dev_2019 = Self_Dev_2019.rename(columns={0:"자기계발"})

x = Self_Dev_2019['Month']
y = Self_Dev_2019["자기계발"]

plt.plot(x, y, color = 'r')
plt.title('2019_자기계발')
plt.xlabel('Month')
plt.ylabel('권 수')

plt.show()

# %% [markdown]
# ### 가설 : 실업률과 자기계발 및 수험서, 언어 외국어 사전(토익 책) 사이에는 양의 상관관계가 있다.
# 즉 실업률이 높으면 자기계발 및 수험서, 언어 외국어 책이 베스트셀러에 많이 올랐을 것이다.

# %%
Unemployment = pd.read_csv("실업.csv", sep = '\t')

# %%
Unemployment.head(4)
# Out:
#         기간   구분     고용지표   고용지표.1   고용지표.2 고용지표.3 고용지표.4 고용지표.5 고용지표.6 고용지표.7  \
# 0       기간   구분  경제활동참가율  경제활동참가율  경제활동참가율    실업률    실업률    실업률    고용률    고용률
# 1       기간   구분       소계       남자       여자     소계     남자     여자     소계     남자
# 2  2008.01  서울시     62.7     74.1       52    4.2    4.6    3.7   60.1   70.7
# 3  2008.02  서울시     62.3     73.7     51.5    4.5      5    3.9   59.5     70
#
#   고용지표.8
# 0    고용률
# 1     여자
# 2   50.1
# 3   49.5

# %%
Unemployment = Unemployment.drop(columns = 
                  ['고용지표.1', '고용지표.2', '고용지표.4', '고용지표.5', '고용지표.7', '고용지표.8']
                  , index = 1)

# %%
new_header = Unemployment.iloc[0] #grab the first row for the header
Unemployment = Unemployment[1:] #take the data less the header row
Unemployment.columns = new_header #set the header row as the df header

# %%
Unemployment = Unemployment.reset_index().drop(columns = 'index')

# %%
Unemployment.head(2)
# Out:
# 0       기간   구분 경제활동참가율  실업률   고용률
# 0  2008.01  서울시    62.7  4.2  60.1
# 1  2008.02  서울시    62.3  4.5  59.5

# %%
Yes24.head(2)
# Out:
#    순위          ISBN             상품명     판매가           저자   출판사  \
# 0   1  9.788984e+12  해리포터와 죽음의 성물 4  7,650원  J.K. 롤링/최인자  문학수첩
# 1   2  9.788984e+12  해리포터와 죽음의 성물 3  7,650원  J.K. 롤링/최인자  문학수첩
#
#                                                   설명          관리분류 Month  Year
# 0  1997년부터 2007년까지, 무려 10년이라는 긴 시간 끝에 해리포터 시리즈 드디...  국내도서-소설/시/희곡     1  2008
# 1  1997년부터 2007년까지, 무려 10년이라는 긴 시간 끝에 해리포터 시리즈 드디...  국내도서-소설/시/희곡     1  2008

# %%
x = Unemployment['기간']
y = Unemployment["실업률"]

plt.plot(x, y, color='g')
axes = plt.gca()
axes.set_ylim([0,30])

plt.title('실업률')
plt.xlabel('Month')
plt.ylabel('Rate of Unemployment')

plt.show()

# %%
Literature = Yes24[Yes24["관리분류"] == '국내도서-소설/시/희곡'].groupby(['Year', 'Month']).size().reset_index()
Literature = Literature.rename(columns={0: "소설/시/희곡"})
Literature['Time-period'] = Literature['Year'].astype(str) + '-' + Literature['Month'].astype(str)
Literature.head(3)
# Out:
#    Year Month  소설/시/희곡 Time-period
# 0  2008     1       17      2008-1
# 1  2008     2       18      2008-2
# 2  2008     3       14      2008-3

# %%
Self_Help = Yes24[Yes24["관리분류"] == '국내도서-자기계발'].groupby(['Year', 'Month']).size().reset_index()
Self_Help = Self_Help.rename(columns={0: "자기계발"})
Self_Help['Time-period'] = Self_Help['Year'].astype(str) + '-' + Self_Help['Month'].astype(str)
Self_Help.head(3)
# Out:
#    Year Month  자기계발 Time-period
# 0  2008     1    12      2008-1
# 1  2008     2    10      2008-2
# 2  2008     3    15      2008-3

# %%
Econ_Biz = Yes24[Yes24["관리분류"] == '국내도서-경제 경영'].groupby(['Year', 'Month']).size().reset_index()
Econ_Biz = Econ_Biz.rename(columns={0: "경제경영"})
Econ_Biz['Time-period'] = Econ_Biz['Year'].astype(str) + '-' + Econ_Biz['Month'].astype(str)

# %%
Language = Yes24[Yes24["관리분류"] == '국내도서-국어 외국어 사전'].groupby(['Year', 'Month']).size().reset_index()
Language = Language.rename(columns={0: "국어 외국어 사전"})
Language['Time-period'] = Language['Year'].astype(str) + '-' + Language['Month'].astype(str)

# %%
Humanities = Yes24[Yes24["관리분류"] == '국내도서-인문'].groupby(['Year', 'Month']).size().reset_index()
Humanities = Humanities.rename(columns={0: "인문"})
Humanities['Time-period'] = Humanities['Year'].astype(str) + '-' + Humanities['Month'].astype(str)

# %%
So_Sci = Yes24[Yes24["관리분류"] == '국내도서-사회 정치'].groupby(['Year', 'Month']).size().reset_index()
So_Sci = So_Sci.rename(columns={0: "사회 정치"})
So_Sci['Time-period'] = So_Sci['Year'].astype(str) + '-' + So_Sci['Month'].astype(str)

# %%
Essay = Yes24[Yes24["관리분류"] == '국내도서-에세이'].groupby(['Year', 'Month']).size().reset_index()
Essay = Essay.rename(columns={0: "에세이"})
Essay['Time-period'] = Essay['Year'].astype(str) + '-' + Essay['Month'].astype(str)

# %%
Child = Yes24[Yes24["관리분류"] == '국내도서-어린이'].groupby(['Year', 'Month']).size().reset_index()
Child = Child.rename(columns={0: "어린이"})
Child['Time-period'] = Child['Year'].astype(str) + '-' + Child['Month'].astype(str)

# %%
Prep = Yes24[Yes24["관리분류"] == '국내도서-수험서 자격증'].groupby(['Year', 'Month']).size().reset_index()
Prep = Prep.rename(columns={0: "수험서 자격증"})
Prep['Time-period'] = Prep['Year'].astype(str) + '-' + Prep['Month'].astype(str)

# %%
Baby = Yes24[Yes24["관리분류"] == '국내도서-유아'].groupby(['Year', 'Month']).size().reset_index()
Baby = Baby.rename(columns={0: "유아"})
Baby['Time-period'] = Baby['Year'].astype(str) + '-' + Baby['Month'].astype(str)

# %%
Wellbeing = Yes24[Yes24["관리분류"] == '국내도서-건강 취미'].groupby(['Year', 'Month']).size().reset_index()
Wellbeing = Wellbeing.rename(columns={0: "건강 취미"})
Wellbeing['Time-period'] = Wellbeing['Year'].astype(str) + '-' + Wellbeing['Month'].astype(str)

# %%
Home = Yes24[Yes24["관리분류"] == '국내도서-가정 살림'].groupby(['Year', 'Month']).size().reset_index()
Home = Home.rename(columns={0: "가정 살림"})
Home['Time-period'] = Home['Year'].astype(str) + '-' + Home['Month'].astype(str)

# %%
Essay.head()
# Out:
#    Year Month  에세이 Time-period
# 0  2008     1    1      2008-1
# 1  2008     2    1      2008-2
# 2  2008     3    2      2008-3
# 3  2008     4    3      2008-4
# 4  2008     5    6      2008-5

# %%
Essay['자기계발'] = Self_Help['자기계발']
Essay['국어 외국어 사전'] = Language['국어 외국어 사전']
Essay['수험서 자격증'] = Prep['수험서 자격증']
Essay['인문'] = Humanities['인문']
Essay['소설/시/희곡'] = Literature['소설/시/희곡']
Essay.head(1)
# Out:
#    Year Month  에세이 Time-period  자기계발  경제경영  인문  소설/시/희곡  국어 외국어 사전  수험서 자격증
# 0  2008     1    1      2008-1    12    10   5       17          8      1.0

# %%
Essay = Essay.drop(Essay.index[-1])
Groups = Essay[['Year', 'Month', 'Time-period', '자기계발', '국어 외국어 사전', '수험서 자격증', '에세이', '소설/시/희곡', '인문']]
Groups.head(3)
# Out:
#    Year Month Time-period  자기계발  국어 외국어 사전  수험서 자격증  에세이  소설/시/희곡  인문
# 0  2008     1      2008-1    12          8      1.0    1       17   5
# 1  2008     2      2008-2    10          9      3.0    1       18   3
# 2  2008     3      2008-3    15          7      1.0    2       14   5

# %%
Unemployment.head(3)
# Out:
# 0       기간  실업률
# 0  2008.01  4.2
# 1  2008.02  4.5
# 2  2008.03  4.1

# %%
data = pd.concat([Groups, Unemployment], axis=1, sort=False)

# %%
data.head(3)
# Out:
#    Year Month Time-period  자기계발  국어 외국어 사전  수험서 자격증  에세이  소설/시/희곡   인문  \
# 0  2008     1      2008-1  12.0        8.0      1.0  1.0     17.0  5.0
# 1  2008     2      2008-2  10.0        9.0      3.0  1.0     18.0  3.0
# 2  2008     3      2008-3  15.0        7.0      1.0  2.0     14.0  5.0
#
#         기간  실업률
# 0  2008.01  4.2
# 1  2008.02  4.5
# 2  2008.03  4.1

# %%
data['실업률']=data['실업률'].astype(float)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), annot=True, fmt='.2f', linewidths=0.2, cmap = sns.diverging_palette(0,255,sep=77, as_cmap=True)
)
plt.show()

# %% [markdown]
# 가설 : 실업률과 자기계발 및 수험서, 언어 외국어 사전(토익 책) 사이에는 양의 상관관계가 있다.
# 즉 실업률이 높으면 자기계발 및 수험서, 언어 외국어 책이 베스트셀러에 많이 올랐을 것이다.
#
# 검증 결과 : 가설 틀림 ㅠ
